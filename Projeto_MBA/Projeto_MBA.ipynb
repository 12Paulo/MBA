# %% [markdown]
# # <font color='blue'>Projeto Market Basket Analysisy</font>

# %% [markdown]
# # O Que é MBA (Market Basket Analysis)?
#
# A Análise de Cesta de Compras (Market Basket Analysis) é uma das principais técnicas usadas por grandes varejistas para descobrir associações entre itens. A técnica funciona procurando combinações de itens que ocorrem juntos com frequência nas transações, ou seja, permite que os varejistas identifiquem as relações entre os itens que as pessoas compram.
#
# A Análise de Cesta de Compras emprega algoritmos de regras de associação e tem como objetivo identificar regras fortes descobertas em dados de transações comerciais usando medidas de interesse.

# %%
## Instalando e Carregando os Pacotes

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.7

# %%
# https://pypi.org/project/efficient-apriori/
#!pip install -q efficient_apriori

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from itertools import combinations
import efficient_apriori
from efficient_apriori import apriori

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Paulo" --iversions
# Out:
# Author: Paulo
#
# efficient_apriori: 2.0.3
# pandas           : 1.2.4
# numpy            : 1.20.3
# matplotlib       : 3.4.3

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega os dados
aisle = pd.read_csv('dados/aisles.csv')
department = pd.read_csv('dados/departments.csv')
order = pd.read_csv('dados/orders.csv')
product = pd.read_csv('dados/products.csv')
order_product_prior = pd.read_csv('dados/order_products__prior.csv')
order_product_train = pd.read_csv('dados/order_products__train.csv')

# %% [markdown]
# ## Análise Exploratória

# %% [markdown]
# Faz sentido calcular a correlação com colunas do tipo ID?

# %%
aisle.shape
# Out:
# (134, 2)

# %%
# Dados do id_corredor e corredor do supermercado
aisle.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
department.shape
# Out:
# (21, 2)

# %%
# Dados do id_departamento e departamento do supermercado
department.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
product.shape
# Out:
# (49688, 4)

# %%
# Dados do id_produto, produto, id_corredor e id_departamento do supermercado
product.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
order.shape
# Out:
# (3421083, 7)

# %%
# Dados do id_pedido, id_cliente, tipo_pedido, numero_pedido, dia_da_semana_pedido, 
# hora_do_dia_pedido e numero_dias_desde_o_pedido_anterior.
order.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_product_prior.shape
# Out:
# (32434489, 4)

# %%
# Dados do id_pedido, id_produto,ordem_do_produto_adicionado_ao_pedido 
# e reordered => verifica se é outra compra do mesmo produto
order_product_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_product_train.shape
# Out:
# (1384617, 4)

# %%
# Conjunto de dados de treino do modelo
# Dados do id_pedido, id_produto,ordem_do_produto_adicionado_ao_pedido
# e reordered => verifica se é outra compra do mesmo produto
order_product_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
# Total de registros por dataset
count_array = np.array([['Aisles', len(aisle)],
                        ['Department', len(department)],
                        ['Product', len(product)],
                        ['Order', len(order)],
                        ['Order_Product_Prior', len(order_product_prior)],
                        ['Order_Product_Train', len(order_product_train)]])
count_record = pd.DataFrame(count_array, columns = ['Arquivo', 'Total de Registros'])
count_record
# Out:
#                Arquivo Total de Registros
# 0               Aisles                134
# 1           Department                 21
# 2              Product              49688
# 3                Order            3421083
# 4  Order_Product_Prior           32434489
# 5  Order_Product_Train            1384617

# %%
# Total de itens nas categorias de eval_set
# prior - verifica se houve pedido anterior
# train - dados de treino
# test - dados de teste
order['eval_set'].value_counts()
# Out:
# prior    3214874
# train     131209
# test       75000
# Name: eval_set, dtype: int64

# %% [markdown]
# ## Limpeza dos Dados

# %% [markdown]
# ### Verificando Valores Ausentes

# %%
aisle.isna().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
department.isna().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
order.isna().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
product.isna().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
order_product_prior.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
order_product_train.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %% [markdown]
# A coluna days_since_prior_order possui valores ausentes, porém a coluna se refere o numero de dias do pedido anterior e pode ser o primeiro pedido do cliente.

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# ### Merge da Tabela order_product_prior com order, product, aisle e department

# %%
# Merge
order_product_prior = order_product_prior.merge(order, on = 'order_id', how = 'left')
order_product_prior = order_product_prior.merge(product, on = 'product_id', how = 'left')
order_product_prior = order_product_prior.merge(aisle, on = 'aisle_id', how = 'left')
order_product_prior = order_product_prior.merge(department, on = 'department_id', how = 'left')

# %%
order_product_prior.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
# 5         2       17794                  6          1   202279    prior
# 6         2       40141                  7          1   202279    prior
# 7         2        1819                  8          1   202279    prior
# 8         2       43668                  9          0   202279    prior
# 9         3       33754                  1          1   205970    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
# 5             3          5                  9                     8.0
# 6             3          5                  9                     8.0
# 7             3          5                  9                     8.0
# 8             3          5                  9                     8.0
# 9            16          5                 17                    12.0
#
#                                         product_name  aisle_id  department_id  \
# 0                                 Organic Egg Whites        86             16
# 1                              Michigan Organic Kale        83              4
# 2                                      Garlic Powder       104             13
# 3                                     Coconut Butter        19             13
# 4                                  Natural Sweetener        17             13
# 5                                            Carrots        83              4
# 6                   Original Unflavored Gelatine Mix       105             13
# 7           All Natural No Stir Creamy Almond Butter        88             13
# 8                            Classic Blend Cole Slaw       123              4
# 9  Total 2% with Strawberry Lowfat Greek Strained...       120             16
#
#                         aisle  department
# 0                        eggs  dairy eggs
# 1            fresh vegetables     produce
# 2           spices seasonings      pantry
# 3               oils vinegars      pantry
# 4          baking ingredients      pantry
# 5            fresh vegetables     produce
# 6  doughs gelatins bake mixes      pantry
# 7                     spreads      pantry
# 8  packaged vegetables fruits     produce
# 9                      yogurt  dairy eggs

# %%
order_product_prior.isna().sum()
# Out:
# order_id                        0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_name                    0
# aisle_id                        0
# department_id                   0
# aisle                           0
# department                      0
# dtype: int64

# %%
order_product_prior.isnull().sum() / len(order_product_prior) * 100
# Out:
# order_id                  0.00000
# product_id                0.00000
# add_to_cart_order         0.00000
# reordered                 0.00000
# user_id                   0.00000
# eval_set                  0.00000
# order_number              0.00000
# order_dow                 0.00000
# order_hour_of_day         0.00000
# days_since_prior_order    6.40697
# product_name              0.00000
# aisle_id                  0.00000
# department_id             0.00000
# aisle                     0.00000
# department                0.00000
# dtype: float64

# %% [markdown]
# Vamos manter a variável days_since_prior_order por duas razões:
#
# 1- O percentual de valores ausentes é apenas de 6.4%.
#
# 2- Não usaremos a variável com o algoritmo MBA.

# %% [markdown]
# ### Merge da Tabela order_product_train com order, product, aisle e department

# %% [markdown]
# O merge nesse caso será dos dados de treino

# %%
# %%time
order_product_train = order_product_train.merge(order, on = 'order_id', how = 'left')
order_product_train = order_product_train.merge(product, on = 'product_id', how = 'left')
order_product_train = order_product_train.merge(aisle, on = 'aisle_id', how = 'left')
order_product_train = order_product_train.merge(department, on = 'department_id', how = 'left')
# Out:
# Wall time: 7.35 s

# %%
order_product_train.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         1       49302                  1          1   112108    train
# 1         1       11109                  2          1   112108    train
# 2         1       10246                  3          0   112108    train
# 3         1       49683                  4          0   112108    train
# 4         1       43633                  5          1   112108    train
# 5         1       13176                  6          0   112108    train
# 6         1       47209                  7          0   112108    train
# 7         1       22035                  8          1   112108    train
# 8        36       39612                  1          0    79431    train
# 9        36       19660                  2          1    79431    train
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             4          4                 10                     9.0
# 1             4          4                 10                     9.0
# 2             4          4                 10                     9.0
# 3             4          4                 10                     9.0
# 4             4          4                 10                     9.0
# 5             4          4                 10                     9.0
# 6             4          4                 10                     9.0
# 7             4          4                 10                     9.0
# 8            23          6                 18                    30.0
# 9            23          6                 18                    30.0
#
#                                     product_name  aisle_id  department_id  \
# 0                               Bulgarian Yogurt       120             16
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                          Organic Celery Hearts        83              4
# 3                                 Cucumber Kirby        83              4
# 4           Lightly Smoked Sardines in Olive Oil        95             15
# 5                         Bag of Organic Bananas        24              4
# 6                           Organic Hass Avocado        24              4
# 7                    Organic Whole String Cheese        21             16
# 8                  Grated Pecorino Romano Cheese         2             16
# 9                                   Spring Water       115              7
#
#                            aisle    department
# 0                         yogurt    dairy eggs
# 1           other creams cheeses    dairy eggs
# 2               fresh vegetables       produce
# 3               fresh vegetables       produce
# 4            canned meat seafood  canned goods
# 5                   fresh fruits       produce
# 6                   fresh fruits       produce
# 7                packaged cheese    dairy eggs
# 8              specialty cheeses    dairy eggs
# 9  water seltzer sparkling water     beverages

# %%
order_product_train.isna().sum()
# Out:
# order_id                  0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# product_name              0
# aisle_id                  0
# department_id             0
# aisle                     0
# department                0
# dtype: int64

# %% [markdown]
# > Vamos agrupar os dados para aplicar o algoritmo Apriori e preparar o dataset com todas as transações.

# %%
# Cria dataframe com 2 colunas sendo a primeira id_pedido e a segunda id_produtos que foram comprados no pedido

order_grouped = pd.DataFrame(order_product_prior.groupby('order_id')['product_id'])
order_grouped.head(10)
# Out:
#     0                                                  1
# 0   2  0    33120
# 1    28985
# 2     9327
# 3    45918
# 4 ...
# 1   3  9     33754
# 10    24838
# 11    17704
# 12    2190...
# 2   4  17    46842
# 18    26434
# 19    39758
# 20    2776...
# 3   5  30    13176
# 31    15005
# 32    47329
# 33    2796...
# 4   6  56    40462
# 57    15873
# 58    41897
# Name: prod...
# 5   7  59    34050
# 60    46802
# Name: product_id, dtyp...
# 6   8         61    23423
# Name: product_id, dtype: int64
# 7   9  62    21405
# 63    47890
# 64    11182
# 65     201...
# 8  10  77    24852
# 78     4796
# 79    31717
# 80    4776...
# 9  11  92    30162
# 93    27085
# 94     5994
# 95     131...

# %%
order_grouped.shape
# Out:
# (3214874, 2)

# %%
len(order_grouped[0])
# Out:
# 3214874

# %%
order_grouped.head()
# Out:
#    0                                                  1
# 0  2  0    33120
# 1    28985
# 2     9327
# 3    45918
# 4 ...
# 1  3  9     33754
# 10    24838
# 11    17704
# 12    2190...
# 2  4  17    46842
# 18    26434
# 19    39758
# 20    2776...
# 3  5  30    13176
# 31    15005
# 32    47329
# 33    2796...
# 4  6  56    40462
# 57    15873
# 58    41897
# Name: prod...

# %%
# Cria uma Lista onde será adicionado os produtos do pedido
prod = []

# %%
for i in range(len(order_grouped[0])):
    prod.append(list(order_grouped.iloc[i][1]))

# %%
# Cria lista com todos os produtos do pedido, cada vetor é o pedido com id dos respectivos produtos
prod_ = prod
prod_
# Out:
# [[33120, 28985, 9327, 45918, 30035, 17794, 40141, 1819, 43668],
#  [33754, 24838, 17704, 21903, 17668, 46667, 17461, 32665],
#  [46842,
#   26434,
#   39758,
#   27761,
#   10054,
#   21351,
#   22598,
#   34862,
#   40285,
#   17616,
#   25146,
#   32645,
#   41276],
#  [13176,
#   15005,
#   47329,
#   27966,
#   23909,
#   48370,
#   13245,
#   9633,
#   27360,
#   6348,
#   40878,
#   6184,
#   48002,
#   20914,
#   37011,
#   12962,
#   45698,
#   24773,
#   18569,
#   41176,
#   48366,
#   47209,
#   46522,
#   38693,
#   48825,
#   8479],
#  [40462, 15873, 41897],
#  [34050, 46802],
#  [23423],
#  [21405,
#   47890,
#   11182,
#   2014,
#   29193,
#   34203,
#   14992,
#   31506,
#   23288,
#   44533,
#   18362,
#   27366,
#   432,
#   3990,
#   14183],
#  [24852,
#   4796,
#   31717,
#   47766,
#   4605,
#   1529,
#   21137,
#   22122,
#   34134,
#   27156,
#   14992,
#   49235,
#   26842,
#   3464,
#   25720],
#  [30162, 27085, 5994, 1313, 31506],
#  [30597,
#   15221,
#   43772,
#   37886,
#   37215,
#   34335,
#   3164,
#   26910,
#   38888,
#   38050,
#   25213,
#   11175,
#   23390,
#   29471,
#   43511],
#  [17330,
#   27407,
#   35419,
#   196,
#   44635,
#   26878,
#   25783,
#   41290,
#   33198,
#   23020,
#   36086,
#   3800,
#   25952],
#  [20392, 27845, 162, 2452, 8575, 41890, 39475, 10096, 23032, 20995, 45066],
#  [19660, 21195, 7461, 2996, 32463],
#  [9755, 25466, 45437],
#  [8021,
#   34969,
#   1000,
#   5212,
#   36011,
#   44632,
#   46969,
#   27966,
#   38985,
#   26648,
#   48745,
#   7948,
#   4802,
#   28934,
#   2116,
#   45495,
#   32018,
#   27644,
#   4656,
#   9848,
#   17568,
#   23339,
#   7308,
#   35547,
#   33279,
#   46979,
#   47766,
#   1057],
#  [42265, 24838, 41540],
#  [35430, 47485, 7419, 5112, 33452, 24852, 42633, 27605],
#  [5009, 33106, 4149, 31478, 25718],
#  [23909,
#   22754,
#   24852,
#   28993,
#   41273,
#   23341,
#   46941,
#   39993,
#   19068,
#   21410,
#   17341,
#   40593,
#   46979,
#   31268],
#  [25931,
#   35163,
#   29662,
#   26283,
#   47766,
#   12036,
#   13497,
#   44953,
#   7969,
#   8518,
#   18689,
#   44299,
#   8381,
#   32205],
#  [40078, 9065, 46175],
#  [9755,
#   31487,
#   37510,
#   14576,
#   22105,
#   1934,
#   6383,
#   39046,
#   48171,
#   33506,
#   30320,
#   15925,
#   37449,
#   48299],
#  [35951, 24852, 46206, 25890, 33120, 21903, 40545, 47766],
#  [13176,
#   30442,
#   13646,
#   21019,
#   38226,
#   18479,
#   47766,
#   17794,
#   42701,
#   21938,
#   5373,
#   28849,
#   41588,
#   3382,
#   19478,
#   28985,
#   49383,
#   40604,
#   8654,
#   2447,
#   24489,
#   26128,
#   15527,
#   41950,
#   20638,
#   27451,
#   10243],
#  [35108,
#   40593,
#   17461,
#   22825,
#   25256,
#   47626,
#   37220,
#   12980,
#   27548,
#   45504,
#   18531,
#   47209,
#   24024,
#   38544,
#   37288,
#   31915],
#  [43352, 21386, 13176, 8571, 33768],
#  [48559, 1158, 42944],
#  [48946, 22935, 21903, 31717, 4920, 25647, 49156, 29926, 47900, 9436],
#  [12384, 15991, 13176, 20995, 18362, 35887, 49683, 4920, 28199],
#  [5699, 32740, 8592, 1446, 46313, 19970, 49390, 32981, 40063],
#  [28413, 24532, 14715, 16974, 37980],
#  [35561, 33059, 43721],
#  [48679, 4605, 28204, 21903, 8385],
#  [10070, 42450, 33198, 34866],
#  [27344, 27355],
#  [19887, 33000, 13176],
#  [20915, 21949, 8817, 37867, 12850, 21553, 34005],
#  [31509, 27979, 20955, 383, 44384, 28012, 27356, 13966, 2240, 17341],
#  [16349],
#  [36884,
#   48183,
#   26172,
#   4778,
#   34519,
#   11983,
#   18346,
#   21067,
#   41602,
#   27656,
#   17417,
#   22282,
#   47827,
#   32917,
#   5077,
#   4447,
#   3703,
#   34233,
#   28921,
#   15364],
#  [16797, 39275, 43352, 46041, 29223],
#  [14129, 22298, 17600, 6141, 42169, 12144, 11403, 36929],
#  [3513, 39276, 20307, 19677],
#  [397, 34993, 17183, 37788, 1025, 4799, 276],
#  [30274, 3594, 14994, 45433, 44514, 32624, 604, 21195, 4493],
#  [18963, 24852, 39408, 49683, 4485],
#  [24852,
#   37646,
#   47209,
#   36606,
#   32442,
#   14467,
#   40706,
#   5876,
#   22298,
#   38827,
#   39275,
#   38647,
#   47626,
#   34448,
#   46194],
#  [10833, 24852, 34004, 35430, 11121, 36086, 32971],
#  [42736,
#   8671,
#   17872,
#   5876,
#   27966,
#   13176,
#   8251,
#   24385,
#   30391,
#   8518,
#   32734,
#   11520,
#   18234,
#   32177,
#   40709,
#   45123,
#   3464,
#   41950,
#   26940,
#   6740,
#   38315,
#   25800],
#  [7021, 4799, 24964, 11520, 9076, 1376, 47209, 21903, 21910, 34050],
#  [21903, 47231, 21137, 43122, 19057, 47209, 48857],
#  [23375, 2825, 22825, 13176, 26604, 42265],
#  [32549, 46077, 12902],
#  [9934,
#   22395,
#   36929,
#   37110,
#   13176,
#   37646,
#   27966,
#   17123,
#   38777,
#   2298,
#   48628,
#   781,
#   13249,
#   22935,
#   890,
#   17794,
#   22963,
#   44910],
#  [42265,
#   22507,
#   4149,
#   29127,
#   15541,
#   13042,
#   20940,
#   10473,
#   17207,
#   38928,
#   6184,
#   16974],
#  [10017, 43394, 37766, 26209, 47766, 28849, 20114],
#  [25886, 41674, 9327, 24203, 34854, 34640, 6046, 287, 12508, 13733],
#  [17889, 9292, 15424, 18988, 38959],
#  [19155, 1940, 25170],
#  [3397, 21955, 38689, 45368, 7658, 37102],
#  [13176, 11422, 27514, 46654, 47993, 5438, 46226, 25670],
#  [43739, 17924, 31805, 9387, 196, 7768, 17207, 1629, 21288],
#  [43875, 27845, 47049, 8186, 34134, 42345, 28682, 36342, 12341, 11140, 23060],
#  [11067, 11481, 44008, 35824],
#  [10017, 12023, 47209, 41544, 5876, 31553, 31717, 26209, 39389, 44632],
#  [28204, 39108, 4472, 43950, 29228, 42548, 20588, 24852, 47479, 38515, 5514],
#  [28413, 24125, 11759, 21903],
#  [46667, 14129, 11136, 27247, 17902, 45681, 7715, 15392, 12456, 14540, 26369],
#  [25138,
#   2361,
#   10915,
#   39275,
#   21616,
#   12341,
#   33768,
#   40709,
#   24889,
#   5959,
#   43889,
#   45646,
#   44077,
#   21019,
#   46383,
#   25195],
#  [31974, 14159, 33357, 38996, 39844],
#  [49510,
#   36481,
#   5120,
#   43154,
#   24184,
#   2295,
#   8277,
#   34969,
#   47626,
#   15290,
#   2979,
#   22935,
#   30391,
#   23233,
#   48057,
#   31040,
#   38944,
#   39619,
#   38273,
#   36550,
#   18079],
#  [32403, 12899, 21573, 32455, 16797],
#  [4210, 4377, 39461, 13627, 13110, 12397, 4840, 11256],
#  [10761, 27845, 42118, 24852, 23734, 2295, 26604],
#  [25931, 43014, 24838, 47209, 15040, 22867, 10385, 21137, 39928, 46394, 44683],
#  [35417, 14117, 3376, 20520, 4421, 39469, 16797, 37646],
#  [13176,
#   1087,
#   35503,
#   4945,
#   40587,
#   11574,
#   37935,
#   43352,
#   39561,
#   2124,
#   13292,
#   12023,
#   4605,
#   10060],
#  [1463, 11193, 34423, 28842, 13984, 42300, 17594, 34065, 18306],
#  [16797, 19691, 32259, 20217, 21349, 33776, 41611, 34063, 42240],
#  [37634, 36004, 45253, 47123, 32566, 23115, 22950, 17706],
#  [16797,
#   39947,
#   31748,
#   44119,
#   38770,
#   49279,
#   2707,
#   45312,
#   40338,
#   46881,
#   6128,
#   13637,
#   4105,
#   46052,
#   8538],
#  [21616,
#   19511,
#   47626,
#   35628,
#   18523,
#   24852,
#   2067,
#   21137,
#   43961,
#   7485,
#   9366,
#   47766,
#   30442,
#   49131,
#   46654,
#   27690,
#   27548,
#   1158,
#   26252,
#   49683,
#   15649,
#   38400,
#   28993],
#  [17794, 20600, 5876, 37011, 26648],
#  [42265, 33043, 890, 44449, 12797],
#  [5825, 44303, 48784, 23293, 42813, 6218],
#  [44116,
#   21903,
#   4793,
#   39121,
#   29742,
#   18288,
#   45633,
#   2929,
#   1376,
#   35503,
#   14332,
#   35704,
#   14540,
#   25230,
#   48385,
#   35561,
#   1392,
#   1374,
#   39928,
#   21137,
#   24852,
#   26604,
#   49235,
#   44375,
#   5646],
#  [13194,
#   47226,
#   28454,
#   33671,
#   39620,
#   23909,
#   39581,
#   27323,
#   42677,
#   4966,
#   39408,
#   13176,
#   29487,
#   25727],
#  [35221, 16521, 11520, 17948],
#  [9337,
#   10121,
#   37630,
#   22035,
#   20379,
#   39928,
#   12395,
#   21137,
#   10849,
#   47766,
#   48464,
#   49683,
#   48287,
#   37158],
#  [4366,
#   17600,
#   12276,
#   30949,
#   46175,
#   36772,
#   30850,
#   44116,
#   25451,
#   2275,
#   28465,
#   10761,
#   19019,
#   33439,
#   34565,
#   35134,
#   38782,
#   38090,
#   33184,
#   1136,
#   37460,
#   28515,
#   4006,
#   37867,
#   41973,
#   27177,
#   29963],
#  [46584, 38200, 13991, 8025, 32105, 35176, 12157],
#  [19660, 196],
#  [6249,
#   1408,
#   5729,
#   9138,
#   16570,
#   4472,
#   21616,
#   44926,
#   47852,
#   3561,
#   37825,
#   47626],
#  [29487, 44625, 27966, 24830, 27104, 39001, 19446, 44570, 26410, 37462],
#  [30850, 5794, 1695, 40386],
#  [28745, 22124, 26604, 5212],
#  [1194,
#   12276,
#   13176,
#   27423,
#   17600,
#   4920,
#   28204,
#   26790,
#   27690,
#   42443,
#   4210,
#   11712],
#  [4210,
#   11210,
#   2839,
#   19836,
#   49505,
#   27288,
#   23011,
#   37449,
#   47144,
#   22620,
#   24184,
#   18019,
#   19539,
#   14168,
#   16177,
#   21938,
#   44455,
#   16370,
#   27509,
#   42548,
#   30958,
#   4497,
#   12945,
#   39335,
#   46167,
#   30413,
#   31562,
#   38819,
#   20114,
#   34092,
#   5048,
#   26179,
#   14936,
#   5672],
#  [35535, 31577, 47783, 30391, 43394, 16953, 11513],
#  [36011, 21847, 14872, 42075, 38381, 7751, 42383, 5212, 13708],
#  [36217,
#   8195,
#   25146,
#   7948,
#   4715,
#   10616,
#   49478,
#   18848,
#   26165,
#   14131,
#   19076,
#   35871,
#   49056,
#   31555,
#   22894,
#   37751,
#   42240,
#   15452,
#   33651,
#   36066,
#   40310],
#  [5876, 35951, 9450, 26216, 21405, 24852, 6873, 34969, 20114, 23689],
#  [16797, 20574, 17461, 15429, 49683],
#  [46654, 35503, 27171, 21903, 19706, 8193, 46313],
#  [24954, 1688, 37371, 5782, 1263, 23763, 24385, 4495, 31164, 31766],
#  [45504,
#   35003,
#   48657,
#   23955,
#   22920,
#   23375,
#   39636,
#   48590,
#   37358,
#   1186,
#   40332,
#   49199],
#  [27104, 42342],
#  [2078,
#   27756,
#   44987,
#   27323,
#   49465,
#   35898,
#   40593,
#   39481,
#   11132,
#   20119,
#   14947,
#   21283,
#   31660,
#   33351,
#   44603],
#  [8571, 21292, 32303, 16283],
#  [18908, 22395, 23400, 17206, 44142, 29987, 31506, 28425, 12572],
#  [40545,
#   26604,
#   28204,
#   41273,
#   48205,
#   42834,
#   31323,
#   1503,
#   46703,
#   5068,
#   28156,
#   26689,
#   33120,
#   19061,
#   39037,
#   11022],
#  [42493, 13372, 3696, 48532, 38579],
#  [17794, 18644],
#  [44632,
#   9839,
#   22035,
#   16825,
#   48246,
#   14917,
#   46823,
#   6692,
#   8859,
#   37464,
#   26604,
#   19048,
#   49273,
#   43908,
#   37646,
#   28123,
#   44683,
#   36010],
#  [44570, 24630, 28527, 21405, 4853, 26698, 11513, 28990],
#  [6656,
#   22035,
#   30489,
#   36550,
#   17835,
#   22963,
#   13176,
#   49215,
#   26282,
#   49235,
#   43961,
#   44359,
#   11068,
#   43249,
#   39619,
#   29987,
#   17948,
#   20549,
#   49175,
#   35750,
#   21777,
#   17807,
#   23074,
#   2002,
#   36735,
#   1463],
#  [14650, 6104, 7054, 25890, 47209, 24866],
#  [16797,
#   9076,
#   23549,
#   37052,
#   4313,
#   25197,
#   7644,
#   47357,
#   45064,
#   9515,
#   15902,
#   39938],
#  [4421, 18770, 24184, 13176, 42265, 16249, 28278, 7010, 41290, 39984],
#  [13176,
#   35628,
#   33454,
#   15649,
#   26634,
#   13198,
#   41950,
#   24850,
#   17471,
#   5194,
#   38995,
#   7067,
#   31073,
#   47509,
#   14715,
#   10017,
#   43338,
#   27845],
#  [39218,
#   4276,
#   14357,
#   18376,
#   24852,
#   33232,
#   12496,
#   8309,
#   19057,
#   44449,
#   34358,
#   9436,
#   35221,
#   3583],
#  [5876,
#   24964,
#   31717,
#   34126,
#   39984,
#   45007,
#   20869,
#   22935,
#   26937,
#   21174,
#   40706,
#   21405,
#   39475,
#   5588,
#   42768,
#   4544,
#   28826,
#   29506],
#  [36640, 17980, 8239, 17830, 39871, 19677, 43295, 48057, 33156, 11447, 25533],
#  [48679, 18670],
#  [43961,
#   17316,
#   14852,
#   30696,
#   169,
#   36076,
#   30169,
#   42460,
#   48423,
#   45763,
#   28156,
#   8638,
#   5547,
#   17029,
#   9018,
#   25952,
#   41970],
#  [25513, 40709, 47866, 13870, 21903, 43513, 31778, 16900, 45951, 49227],
#  [47766, 18465, 29926, 11005],
#  [24363, 29625, 22935, 15995, 38890, 28432],
#  [14678, 19678, 22935, 21903, 33731, 2386],
#  [4516, 2712, 44560, 35042, 7898, 43154, 32655, 18721, 22618],
#  [21131,
#   16696,
#   43616,
#   42972,
#   6991,
#   1694,
#   36316,
#   23909,
#   34185,
#   43693,
#   32650,
#   30913,
#   13641,
#   13627,
#   10957],
#  [19348, 15979, 20269, 24186, 32638, 46222, 46261],
#  [47626,
#   15386,
#   24852,
#   4605,
#   8518,
#   49098,
#   34067,
#   36070,
#   3148,
#   15902,
#   45066,
#   18498,
#   22866,
#   24838,
#   47185,
#   13802,
#   12218,
#   43183,
#   26040,
#   46844,
#   42352,
#   37611,
#   14850,
#   29529,
#   277],
#  [45437,
#   35921,
#   43394,
#   12384,
#   1503,
#   24799,
#   22474,
#   8424,
#   46069,
#   26047,
#   45948,
#   19448,
#   17794,
#   7948],
#  [31651, 35898, 26348],
#  [12078,
#   13575,
#   43352,
#   21288,
#   32303,
#   26348,
#   41400,
#   30591,
#   19660,
#   16797,
#   37710,
#   13914,
#   24135],
#  [432,
#   26346,
#   21938,
#   24184,
#   4605,
#   5605,
#   23537,
#   12838,
#   17794,
#   31433,
#   31553,
#   1360],
#  [38650,
#   25659,
#   35951,
#   34197,
#   11712,
#   26940,
#   48364,
#   21903,
#   14881,
#   34720,
#   1158,
#   26606,
#   47209,
#   21614],
#  [15383, 33129, 2390],
#  [14127, 45645, 21506],
#  [46931, 26152, 48697, 30486],
#  [13176, 6184, 5161, 4557, 40969],
#  [26620, 12576, 40632, 40599, 47717, 33716, 48493, 19448, 23765],
#  [30489, 25246, 41801, 11806],
#  [7308, 10749, 19048, 17619, 18531, 27243],
#  [35383, 13829, 42719, 12276, 46720],
#  [42768, 3494, 1529, 37193, 39275, 13984, 43789],
#  [27966, 16387, 15712, 37022, 49683, 24852, 11422, 47209],
#  [21616, 30391, 17949, 5479],
#  [31915, 21137, 24390, 25477, 25331],
#  [40310, 14464, 34047, 32691, 12276, 48800, 48097, 32141, 17334],
#  [17560, 7503, 38944, 47766, 27104, 45007, 32959, 38666, 26032, 35750, 8955],
#  [21616,
#   16185,
#   30391,
#   33731,
#   39877,
#   35715,
#   13176,
#   27966,
#   47888,
#   26209,
#   29077,
#   31640,
#   4920,
#   19240,
#   14211,
#   26301,
#   11520,
#   30252,
#   30489],
#  [40332, 32689, 47626, 28985, 6779, 39563],
#  [10017, 27521, 13838, 22921, 20178, 34339, 47626, 38647, 13130],
#  [6690, 21524, 25760, 13536, 15805, 11472, 19850, 47734, 17251],
#  [10957, 6623, 19019, 32303],
#  [27344, 41836, 20580, 18366, 19736, 38145],
#  [21903, 45066, 25370, 36777, 25980, 8021, 25020, 8230, 6341],
#  [14645, 48226],
#  [18441, 33279, 22507, 651],
#  [42325, 14409, 14833, 34124, 17419, 30169],
#  [24852,
#   44422,
#   7503,
#   43961,
#   28204,
#   30884,
#   11819,
#   32016,
#   24964,
#   1463,
#   27104,
#   14332,
#   41257,
#   19184],
#  [3025,
#   5479,
#   24852,
#   1516,
#   12015,
#   44349,
#   28934,
#   11777,
#   32433,
#   27966,
#   44683,
#   46346,
#   48720,
#   28849],
#  [5876, 26497, 17872, 4675, 21267, 22825, 41588, 22935, 5991, 8518],
#  [21903,
#   40723,
#   27531,
#   1158,
#   37766,
#   48299,
#   46802,
#   38159,
#   35055,
#   40311,
#   5022,
#   19906,
#   29987,
#   9076,
#   43352,
#   33731,
#   24852],
#  [49235, 6369],
#  [40604, 31040, 31242, 30382, 31343, 21616],
#  [37385,
#   27521,
#   18234,
#   35163,
#   31717,
#   5876,
#   24933,
#   17948,
#   26604,
#   22825,
#   13176,
#   41960,
#   5825,
#   21938,
#   47209,
#   16521,
#   7079],
#  [20995, 35166, 8903, 38456, 24852, 7461, 14084, 33746],
#  [4305, 23789, 6376, 49628, 31215, 11512, 49247],
#  [21962, 24852, 45265, 23405, 23431, 16797, 9710, 1080],
#  [23165, 24964, 39812, 11520, 41556, 27392, 20899, 5134, 37825, 37029],
#  [7781, 44085, 20082, 43692, 14947, 41351, 25830, 28892, 20314],
#  [24852, 30183, 41351, 31869, 6128, 34862, 4595, 16797, 5077, 23687],
#  [26497, 38275, 38419, 1025, 48679, 30305],
#  [35986, 18718, 19660, 2966, 19894],
#  [21903, 34243, 16797, 23543, 3957, 48104, 25659, 22395, 23400, 42768, 22959],
#  [24325, 41391, 29116, 12811, 2178],
#  [5876,
#   49476,
#   9598,
#   18224,
#   36082,
#   8174,
#   12456,
#   15700,
#   18413,
#   19240,
#   29117,
#   43295,
#   47253,
#   5677,
#   33527],
#  [12409,
#   45946,
#   32028,
#   21291,
#   3873,
#   13176,
#   35921,
#   36646,
#   42001,
#   3545,
#   49075,
#   29594],
#  [3149, 13514, 28012, 1860, 45, 16275, 3990, 29252],
#  [13176,
#   3066,
#   13629,
#   33845,
#   36522,
#   43955,
#   11408,
#   9366,
#   5746,
#   4799,
#   39329,
#   16797,
#   38777,
#   49683,
#   30103,
#   34664,
#   22654,
#   23734,
#   32839,
#   31343,
#   37985,
#   38188,
#   33043,
#   25753,
#   34851],
#  [13740, 39561, 49396, 32293, 30774, 21137, 24838, 25931, 33352, 4562],
#  [2994, 21137, 45535, 6347, 46709, 19660, 42585, 30450, 3142, 47630],
#  [33000, 32374, 2421, 20842, 24852, 15740, 45368, 21417, 47893, 27778],
#  [1503, 13070, 23217, 13176, 5077, 15097, 1688],
#  [9434, 196, 19660],
#  [28476, 40486, 4605, 8262, 39507, 14499, 15269, 27323],
#  [20406],
#  [26348],
#  [45368, 28682, 29987, 39812, 31343, 38885],
#  [25146, 28836, 5785],
#  [47626, 40174, 16607, 39928, 20142, 41787, 20211],
#  [5385, 27360, 22128, 2408, 7860, 44337],
#  [35350,
#   36681,
#   32429,
#   34503,
#   1582,
#   28632,
#   24852,
#   36849,
#   45066,
#   48395,
#   36736,
#   3880,
#   44926,
#   34050],
#  [39409, 20842, 16965, 8021, 23001],
#  [47626,
#   5479,
#   48679,
#   44683,
#   29650,
#   46969,
#   45066,
#   27104,
#   7948,
#   5161,
#   41757,
#   37067,
#   26324,
#   39261,
#   10286,
#   10504,
#   86],
#  [46654, 16797],
#  [17122, 21137, 40120, 8953],
#  [46064,
#   27156,
#   9390,
#   9076,
#   46802,
#   1158,
#   28553,
#   21077,
#   21903,
#   24852,
#   26165,
#   11941],
#  [5499, 8424, 37053, 24852, 21329, 25093, 25043, 25890, 40545],
#  [49235, 37215],
#  [32850, 49520, 26521, 21137, 10831, 8667, 3849, 14947],
#  [11262, 3142, 1360],
#  [13176, 7987, 21903, 43352],
#  [3919, 11432, 14992],
#  [24010, 4658, 39097, 40699, 5926, 39046, 37797, 4210, 32156],
#  [24852,
#   47626,
#   35522,
#   21903,
#   25043,
#   8424,
#   28204,
#   45613,
#   14267,
#   25146,
#   42768,
#   49667,
#   44765,
#   38273,
#   31343,
#   38012,
#   35510,
#   46993],
#  [23240,
#   24852,
#   44799,
#   39604,
#   46541,
#   40733,
#   46172,
#   47842,
#   19953,
#   4895,
#   33852,
#   15483,
#   4674,
#   5636,
#   29487,
#   5450,
#   41245,
#   5025,
#   4605,
#   1700,
#   307,
#   14992,
#   26283,
#   27147,
#   6165,
#   1181,
#   3999],
#  [47138,
#   148,
#   1940,
#   49235,
#   35003,
#   33548,
#   14910,
#   34,
#   45681,
#   22620,
#   19660,
#   43409,
#   27244,
#   46817,
#   12863,
#   26767,
#   21694],
#  [1559, 24852, 21709, 24041, 37646, 8277, 33100, 47087, 14947, 36011, 32655],
#  [45066, 9551, 25919, 31624, 32784, 36070],
#  [24489,
#   30391,
#   7577,
#   43086,
#   36183,
#   36406,
#   36070,
#   21174,
#   23054,
#   47439,
#   45368,
#   34217,
#   45613,
#   890,
#   28849,
#   49175,
#   7628,
#   24964,
#   41953,
#   46206,
#   48716,
#   8728,
#   47209,
#   13176,
#   19709,
#   25122,
#   36550,
#   16757,
#   34224,
#   27966,
#   29180],
#  [21108, 34276, 27730, 42495, 11782, 41690, 17821, 18266, 25435, 14579, 40824],
#  [46667, 26384, 4925, 41177, 32689, 34126, 36953],
#  [46666,
#   40203,
#   45896,
#   14464,
#   36307,
#   44254,
#   25830,
#   23621,
#   14875,
#   27845,
#   10673,
#   26552,
#   8572,
#   4932,
#   8409,
#   1197,
#   32265,
#   44234,
#   26824,
#   11381,
#   21281,
#   28569,
#   4798,
#   29471],
#  [17835,
#   40501,
#   13176,
#   39534,
#   27086,
#   44204,
#   10132,
#   4792,
#   7521,
#   29558,
#   39055,
#   29142,
#   28745,
#   21137,
#   17794,
#   8193,
#   22935,
#   37458,
#   45633,
#   37220,
#   22504,
#   44293],
#  [9076, 43352, 21288],
#  [46313, 33401, 8424, 24964, 39275, 24489, 19019, 2086, 4208, 46372],
#  [10749,
#   29447,
#   19816,
#   12099,
#   13176,
#   44632,
#   10070,
#   30233,
#   15290,
#   25824,
#   44090,
#   41623],
#  [44632, 6218, 24838, 44257, 45645, 31824, 25890, 21616, 45066, 41774, 10132],
#  [47626],
#  [9124, 35503, 34217, 23417],
#  [22959,
#   24838,
#   37646,
#   36764,
#   35921,
#   41844,
#   13740,
#   47209,
#   48679,
#   9339,
#   29118,
#   35750,
#   34126,
#   16744,
#   5194,
#   19382,
#   21903,
#   27544],
#  [35121,
#   29127,
#   27985,
#   14129,
#   46720,
#   18880,
#   4889,
#   9076,
#   2846,
#   24010,
#   29978,
#   39275,
#   8639,
#   5258],
#  [47626, 46979, 40332, 39046, 23623],
#  [19691, 16797, 13176],
#  [22281, 37890, 42450, 41213, 37067, 45200],
#  [22935, 35921, 31506, 48679, 8412, 45066, 43122, 19208, 47209, 7014],
#  [32455, 10509],
#  [36550, 5785, 34557],
#  [2979,
#   30135,
#   2969,
#   28058,
#   16262,
#   5801,
#   6106,
#   31596,
#   29683,
#   39239,
#   4496,
#   34688,
#   11051,
#   4422,
#   49185,
#   23204],
#  [7963,
#   38508,
#   22963,
#   21903,
#   44359,
#   19057,
#   30718,
#   33911,
#   36714,
#   9689,
#   26476,
#   37630,
#   21653,
#   8021],
#  [27307,
#   13535,
#   18908,
#   35767,
#   42719,
#   41950,
#   21616,
#   14159,
#   8955,
#   10644,
#   7806,
#   8021,
#   30290],
#  [17902, 38775],
#  [12409,
#   21903,
#   30391,
#   46667,
#   23178,
#   13176,
#   21616,
#   8518,
#   22935,
#   7179,
#   7936,
#   5876,
#   1158,
#   5652,
#   48679,
#   24838,
#   26606,
#   6160,
#   8774,
#   44910,
#   26369,
#   43789,
#   31717,
#   3464,
#   23375],
#  [11512, 39984, 46886, 39599, 39190, 10749, 14814, 31717],
#  [46667, 25256, 47868],
#  [44275,
#   27966,
#   27695,
#   45840,
#   4957,
#   5077,
#   13176,
#   17949,
#   22035,
#   21137,
#   26329,
#   5134,
#   1194,
#   40706,
#   10753,
#   16254,
#   44560,
#   37766,
#   38293,
#   5240,
#   1408,
#   18471,
#   32578,
#   26790,
#   11130,
#   48953,
#   33731,
#   47521,
#   7021,
#   43904,
#   47629,
#   35688],
#  [30945,
#   31748,
#   16508,
#   47479,
#   42085,
#   34279,
#   47565,
#   44731,
#   34358,
#   872,
#   29156,
#   42345,
#   47049,
#   23527,
#   24852],
#  [19348,
#   47993,
#   28842,
#   2180,
#   44142,
#   48174,
#   43205,
#   43875,
#   47888,
#   47366,
#   47052,
#   3808,
#   45607,
#   16556,
#   29821,
#   36533,
#   43958],
#  [24852,
#   9387,
#   22825,
#   46969,
#   3085,
#   16797,
#   39275,
#   6348,
#   27086,
#   46676,
#   33754,
#   18523,
#   47029,
#   48726,
#   45066],
#  [3957,
#   1169,
#   43295,
#   6568,
#   6287,
#   20947,
#   17333,
#   20794,
#   44632,
#   44422,
#   11688,
#   22227,
#   33462],
#  [37011,
#   29930,
#   20589,
#   46823,
#   42585,
#   23634,
#   24852,
#   49683,
#   41453,
#   36023,
#   9809,
#   18583,
#   44042,
#   36956,
#   21227,
#   7542],
#  [25890, 16185, 46654, 24009, 28156, 46906, 18567, 49533, 19348, 17638],
#  [23339, 34969, 24561, 6677],
#  [34368, 4180, 42431, 37449],
#  [39023, 14897, 31553, 47865],
#  [13838,
#   27845,
#   13176,
#   41658,
#   18370,
#   3896,
#   10768,
#   33731,
#   12745,
#   32689,
#   21137,
#   43352,
#   26604,
#   38772,
#   20431,
#   29898,
#   17224,
#   38656,
#   18281,
#   19678,
#   21162,
#   2141,
#   1347,
#   42701,
#   18200,
#   13776,
#   27626,
#   4920,
#   9806,
#   7021,
#   46667,
#   31717,
#   32656,
#   5373,
#   21927,
#   22935],
#  [41950, 15923, 24186, 34126, 14005, 45854, 39772, 43183, 34358],
#  [39877, 30707, 22825, 35264, 21137, 42768, 39180, 8518, 26369],
#  [44340],
#  [35715],
#  [22275, 14999, 21641, 33189, 30776, 32109],
#  [21372, 42117, 5334, 20112],
#  [35752,
#   2119,
#   24279,
#   3308,
#   47772,
#   1583,
#   37886,
#   33109,
#   812,
#   31377,
#   17615,
#   33184,
#   34931,
#   10897,
#   19003,
#   41729,
#   4920,
#   1022,
#   36086,
#   21288],
#  [15131, 16615, 12305, 17896, 19674, 45877, 35298, 5782],
#  [48094,
#   24852,
#   27156,
#   28204,
#   31506,
#   17872,
#   35535,
#   5337,
#   32760,
#   13198,
#   41238,
#   34530,
#   18963],
#  [24852,
#   8277,
#   4799,
#   33731,
#   27156,
#   22853,
#   37270,
#   20995,
#   22031,
#   9755,
#   47042,
#   28986,
#   17284],
#  [47672, 37158, 21938, 14678, 34243, 24497, 18242, 28553],
#  [21903, 6383, 21616, 41148, 49610, 49683, 28581, 15290, 43768],
#  [15269, 47626, 42495, 9387, 41264, 3880],
#  [22959,
#   24852,
#   43014,
#   23630,
#   27122,
#   2002,
#   19156,
#   24489,
#   17948,
#   34684,
#   436,
#   21903,
#   47626,
#   17794,
#   35887],
#  [29672,
#   432,
#   23102,
#   44765,
#   19057,
#   30233,
#   47766,
#   22035,
#   21137,
#   17708,
#   25936,
#   36792,
#   2732,
#   21607,
#   38293,
#   8518,
#   13176,
#   31238,
#   45002,
#   17284,
#   9521,
#   6046,
#   7358,
#   13829,
#   44359,
#   31717,
#   21387,
#   17600,
#   10126],
#  [43379, 26209, 24852, 47766, 15290, 30391, 26800, 21903, 20163, 45066],
#  [2727, 21338, 23767, 43892],
#  [21883, 41273, 41131, 4187],
#  [7175, 3142, 35461, 48720, 43154, 24964, 14852, 36322, 45767, 13176],
#  [31343, 49247, 49075, 812, 3599, 16825],
#  [10102,
#   5450,
#   11182,
#   24184,
#   24852,
#   41950,
#   13966,
#   22699,
#   47144,
#   23909,
#   20166,
#   43352,
#   14161,
#   49683,
#   12032,
#   32528],
#  [12206, 29987, 23909, 21927, 41220, 28071, 41290],
#  [24852,
#   9387,
#   47492,
#   14870,
#   31553,
#   38281,
#   17948,
#   17794,
#   49683,
#   28985,
#   10749,
#   42585,
#   34099],
#  [6111,
#   1234,
#   37646,
#   42701,
#   12341,
#   2664,
#   25821,
#   39200,
#   48775,
#   27117,
#   48946,
#   920,
#   18254,
#   17025,
#   34134,
#   18079,
#   10749,
#   4001,
#   9808],
#  [14722, 46676, 32331, 43772, 2172, 8214],
#  [16150, 19213, 39732, 24852, 3090, 7350, 3957, 27966],
#  [21137,
#   28199,
#   8174,
#   13176,
#   47209,
#   24768,
#   21872,
#   6873,
#   47734,
#   17948,
#   10305,
#   36848,
#   29388,
#   48179],
#  [48109,
#   16549,
#   24499,
#   23836,
#   48857,
#   42736,
#   19660,
#   44661,
#   34605,
#   16611,
#   31662,
#   2228,
#   48179,
#   258,
#   16262,
#   21108,
#   36481,
#   21092],
#  [19934, 9779, 47119],
#  [19437, 9839, 261, 432],
#  [15261, 8518, 14578, 6287],
#  [28079,
#   40898,
#   20255,
#   17484,
#   26317,
#   30385,
#   27845,
#   27104,
#   46979,
#   4605,
#   4853,
#   47766,
#   28993,
#   45,
#   28849,
#   41658],
#  [49026, 19794, 15518, 15984, 24859, 46822],
#  [43154, 14161, 26604, 39275, 16797, 12341, 10326],
#  [47766, 21903, 47780, 31553],
#  [36406, 25010, 45603, 2966, 35942, 24549],
#  [49235,
#   28427,
#   47144,
#   20463,
#   1940,
#   1181,
#   4377,
#   6473,
#   8953,
#   30391,
#   22034,
#   4086,
#   260],
#  [42224, 6184, 13176],
#  [13198, 28934, 49683, 13646, 10305, 29941],
#  [36372, 44632, 21709, 2717, 22556, 17191, 31964],
#  [35561,
#   46955,
#   45007,
#   19057,
#   39560,
#   12144,
#   25715,
#   45633,
#   27966,
#   5785,
#   13176,
#   162,
#   45767,
#   35851,
#   48726,
#   4663,
#   47144],
#  [15541, 26152, 10246, 196, 19660, 18067],
#  [17025, 32134, 20574, 12614, 24852, 45066, 9076, 8518, 41220, 18027, 19019],
#  [13255],
#  [44042,
#   44799,
#   23909,
#   21938,
#   16464,
#   7326,
#   20031,
#   32433,
#   48702,
#   42215,
#   17322,
#   39735,
#   35825,
#   48927],
#  [30233, 13176, 23801, 42265, 38837],
#  [39898, 54, 35359],
#  [27086, 19398, 20299],
#  [32429,
#   39408,
#   21137,
#   43352,
#   39275,
#   18721,
#   41376,
#   26604,
#   47766,
#   15462,
#   17616,
#   45840,
#   45724,
#   47626,
#   6184,
#   23029,
#   7781,
#   3631,
#   38777,
#   40469,
#   6587,
#   45692,
#   22525,
#   13740,
#   42383,
#   48666,
#   34941,
#   42342,
#   42327,
#   12639,
#   21511,
#   47740,
#   21272,
#   6074,
#   45681,
#   46175,
#   36115,
#   45161],
#  [5258, 31805, 196, 12341, 21573, 36051, 19828],
#  [42450,
#   42768,
#   45007,
#   47626,
#   46969,
#   18078,
#   33294,
#   27104,
#   43673,
#   2380,
#   32256,
#   24184,
#   29079,
#   45578,
#   47734,
#   49588,
#   25005,
#   47993,
#   12276,
#   36639,
#   30953],
#  [21616, 27939, 22963, 24830, 21661],
#  [5337, 13176, 30827, 38768, 17207, 41787, 9387, 39408, 2515],
#  [39947, 39275, 14218, 39032, 16797, 40348],
#  [21497,
#   31683,
#   33674,
#   44661,
#   24852,
#   12099,
#   21137,
#   7781,
#   27845,
#   16885,
#   28993,
#   9808,
#   42265,
#   45066,
#   4799,
#   30489,
#   27113,
#   20040,
#   21376,
#   21850,
#   2081,
#   9076],
#  [13819, 432, 19311, 36646, 28842, 41259, 4605, 46526, 37011],
#  [47209,
#   4451,
#   24852,
#   17027,
#   27548,
#   39121,
#   21267,
#   30442,
#   14872,
#   22888,
#   6873,
#   8277],
#  [32538, 16797, 19660],
#  [8559, 8781, 8671, 27178, 23405],
#  [429,
#   35042,
#   21010,
#   27985,
#   23219,
#   43565,
#   21491,
#   5603,
#   15290,
#   11422,
#   23102,
#   22312,
#   43742,
#   2225,
#   30623,
#   5913,
#   39477],
#  [19660, 11974, 26410, 41621, 33120, 23459, 32373, 44683],
#  [43394, 21137, 13740, 9438, 15011, 27845, 24157, 2237, 5818, 41165, 35004],
#  [24852,
#   33793,
#   4210,
#   11821,
#   5077,
#   19125,
#   47660,
#   2050,
#   27681,
#   47766,
#   12621,
#   48746,
#   36291,
#   16897,
#   49621,
#   46473,
#   40319,
#   33184,
#   16219,
#   38100,
#   14290,
#   22774,
#   42736,
#   39054,
#   2350,
#   23734,
#   46654,
#   45104],
#  [24024, 10586, 40761, 20574, 46802],
#  [44632,
#   38456,
#   25146,
#   30884,
#   17570,
#   18105,
#   6846,
#   19125,
#   17535,
#   46257,
#   38941,
#   29256,
#   19129,
#   33198,
#   28985,
#   42731,
#   37892,
#   7628,
#   34969,
#   45,
#   7419,
#   41771,
#   35072,
#   38562,
#   13176,
#   47626,
#   31553,
#   15945],
#  [24852, 28156, 2962, 28842, 41352, 18761],
#  [30169, 46676, 24838, 39581, 2091, 12817, 6991],
#  [28, 40574, 32544, 34027, 39407, 17505, 2966],
#  [16462,
#   30442,
#   42736,
#   8277,
#   27966,
#   16797,
#   38456,
#   45007,
#   21295,
#   47766,
#   24184,
#   5134,
#   30489,
#   25936,
#   691,
#   8467,
#   21302],
#  [6187,
#   25146,
#   8022,
#   42342,
#   9407,
#   28204,
#   19559,
#   45681,
#   31433,
#   16083,
#   24852,
#   24964,
#   17794,
#   18656,
#   18200],
#  [9839,
#   27086,
#   16773,
#   21903,
#   45437,
#   47144,
#   39409,
#   8277,
#   20345,
#   43802,
#   43192,
#   46049,
#   47668,
#   4656,
#   48171,
#   37158,
#   10166,
#   26346,
#   42736,
#   43713,
#   24852,
#   48450],
#  [24852,
#   43352,
#   35221,
#   11689,
#   25197,
#   15955,
#   31268,
#   3856,
#   47626,
#   26209,
#   19348,
#   33548,
#   22298,
#   37671,
#   40742,
#   12341,
#   45066,
#   33129,
#   13823,
#   38905,
#   16797,
#   1437,
#   17341,
#   17149,
#   1737,
#   15130],
#  [27639, 30353, 13176, 11520, 5456, 45007, 19678],
#  [26604,
#   4945,
#   2295,
#   31504,
#   14643,
#   8277,
#   13198,
#   27845,
#   8424,
#   30994,
#   4920,
#   3874,
#   25824,
#   37119,
#   33593,
#   45681,
#   1215,
#   37029,
#   49683],
#  [26165],
#  [36406, 46906, 12075, 38809, 19635, 7139, 37665, 1450, 39877, 30169, 33754],
#  [24852, 16507, 22825, 17219, 27845, 3081, 43428],
#  [7693, 49520, 35221, 24152, 42137, 29689, 47815, 31992],
#  [1498, 44843, 49363, 3996, 1200, 17505, 8732, 13287, 14168, 14705, 17600],
#  [18523, 47209, 33787, 33754, 45104, 34358],
#  [30776,
#   48559,
#   49026,
#   27966,
#   21903,
#   44359,
#   18689,
#   47209,
#   32864,
#   24889,
#   43086,
#   17304,
#   17948,
#   1158],
#  [19348, 8153, 21573, 9387],
#  [13176,
#   5785,
#   23288,
#   44632,
#   20119,
#   2825,
#   28156,
#   22963,
#   47209,
#   5212,
#   39877,
#   22825,
#   43122,
#   23029,
#   19987,
#   37646,
#   30529,
#   8912,
#   16384,
#   39035,
#   32647],
#  [33731, 4799, 35749, 20791, 41621, 24841, 10199, 40215, 22548],
#  [31915, 47209, 10749, 13176, 36606, 13497, 25533, 35898, 26452, 4605],
#  [43352, 47626, 8174, 23341, 16219, 17914, 196, 13966, 31683],
#  [33548,
#   44156,
#   24852,
#   21925,
#   28204,
#   7736,
#   23296,
#   23106,
#   33791,
#   20561,
#   12524,
#   40332,
#   287,
#   10995,
#   13733,
#   34619,
#   16826],
#  [790, 22556, 13176],
#  [9852, 26497, 41176, 44142, 17389],
#  [907, 769, 48762, 38775, 45004],
#  [18770,
#   39180,
#   27086,
#   39947,
#   33731,
#   44632,
#   11941,
#   22935,
#   21709,
#   28278,
#   21267,
#   26209,
#   8087,
#   22825,
#   21903,
#   39877,
#   6873,
#   3339,
#   46979,
#   18908,
#   33401,
#   3849,
#   29898,
#   27156,
#   25659,
#   37158,
#   9515],
#  [742, 29694, 38051, 16823, 44580, 42585, 22234, 35417, 30489, 43961],
#  [32433,
#   28934,
#   34358,
#   46667,
#   31717,
#   20114,
#   16759,
#   391,
#   36389,
#   33746,
#   41259,
#   33294,
#   18027,
#   24852,
#   8479,
#   2846,
#   17600,
#   9076,
#   10025,
#   22307,
#   39561,
#   34448,
#   48190,
#   21137],
#  [10339, 49519, 48453, 22832, 48210, 4455, 1450],
#  [39877, 13176, 35140, 36036, 27999, 30427, 5876],
#  [13984, 45007, 39877, 21903, 5785],
#  [25466, 14240, 42265],
#  [3849, 47209, 21137, 35951, 9550, 39905, 38777, 30391, 41858],
#  [27845,
#   24852,
#   26384,
#   26209,
#   16908,
#   47766,
#   22170,
#   28682,
#   45066,
#   24841,
#   1935,
#   21326,
#   48628,
#   46667,
#   49481,
#   46107,
#   16797,
#   23074,
#   24231],
#  [31553, 33772, 23687],
#  [36051, 19887, 17122, 37687],
#  [9690, 41658, 22935, 27845, 47553, 49533, 7021, 41909],
#  [24852,
#   27086,
#   46820,
#   21709,
#   3952,
#   21903,
#   46620,
#   46979,
#   23094,
#   2295,
#   44765,
#   18232,
#   13877],
#  [18656, 25824, 45, 8177, 30305, 39922, 6015],
#  [47337, 5097, 41722, 12218, 35042, 31022, 40348, 19461],
#  [38159, 26606, 5785, 39527, 43154],
#  [7559, 2581, 43122, 1846, 23516, 38274, 37642, 8518],
#  [2716, 47029, 45210, 35851, 8277, 16462, 890],
#  [19678, 21405, 38383, 38153, 28928, 18288, 26032, 29228, 13805, 33000, 14129],
#  [13249, 43693],
#  [12606, 5450, 46823, 310, 14678, 26128, 13176, 44643],
#  [21137,
#   21903,
#   34358,
#   42768,
#   24852,
#   39993,
#   46906,
#   27730,
#   44479,
#   46654,
#   19508,
#   3376,
#   25890,
#   35784],
#  [46123,
#   33731,
#   38689,
#   6519,
#   2966,
#   21560,
#   5479,
#   27864,
#   43961,
#   2086,
#   44449,
#   30953,
#   5383,
#   32299,
#   47209,
#   41658,
#   19019,
#   5959,
#   24382,
#   35108,
#   18564,
#   40001],
#  [33198,
#   31801,
#   9038,
#   21137,
#   19660,
#   7963,
#   47717,
#   45066,
#   25256,
#   9322,
#   35628,
#   22227,
#   23630,
#   27959,
#   10212,
#   21405],
#  [3678],
#  [30233, 17619, 26313, 26209, 33106, 28842, 13176, 13866],
#  [28050, 39619, 18531, 48679, 8021, 2086],
#  [12916, 2457, 13032, 40688, 39275, 16797, 32538, 35561, 19380, 32403, 19887],
#  [21841,
#   30776,
#   3957,
#   8424,
#   650,
#   28360,
#   15937,
#   24964,
#   34243,
#   46667,
#   20114,
#   31717,
#   4605,
#   26209,
#   8736,
#   45603,
#   44283,
#   29871,
#   10482,
#   44257,
#   32981,
#   43961,
#   17872,
#   6740,
#   45007],
#  [11781, 16856],
#  [19660,
#   34197,
#   35503,
#   3957,
#   24447,
#   39108,
#   33198,
#   1639,
#   12039,
#   3631,
#   35628,
#   8575,
#   47042,
#   29662,
#   27925,
#   44479,
#   31717,
#   7185,
#   40996,
#   14881,
#   24964,
#   8006,
#   40706,
#   26940,
#   41065,
#   29594,
#   25005,
#   33120,
#   24830,
#   2825,
#   38274,
#   22504,
#   23516,
#   5449],
#  [40910, 9175, 31299, 8668, 22233, 36227, 40285, 44632],
#  [13944, 28931, 19309, 17084, 22915, 16020],
#  [2855, 26088, 20955, 42282],
#  [24852,
#   35321,
#   15319,
#   3896,
#   46616,
#   30489,
#   20114,
#   24184,
#   25513,
#   20549,
#   21616,
#   40604,
#   32284],
#  [26165, 28990, 8460, 28511, 8193, 29487, 44042],
#  [35547, 47626, 26209],
#  [39108,
#   7781,
#   18465,
#   28985,
#   30305,
#   45007,
#   16249,
#   19906,
#   7058,
#   44683,
#   38996,
#   44234,
#   24852,
#   30620,
#   41950,
#   890,
#   18880,
#   7364,
#   36070,
#   25919,
#   44142,
#   3913,
#   9076,
#   43086],
#  [26369],
#  [37912,
#   37766,
#   5161,
#   5785,
#   43122,
#   25340,
#   41315,
#   45066,
#   28790,
#   13176,
#   37011,
#   22935,
#   17794,
#   44359,
#   7021,
#   41544,
#   39812,
#   35333,
#   34126,
#   37508,
#   43713,
#   40377,
#   18465],
#  [12863, 13263, 39009],
#  [14870, 17594, 25013],
#  [20119,
#   26620,
#   24852,
#   22124,
#   22035,
#   432,
#   6348,
#   39475,
#   25718,
#   21709,
#   35168,
#   7969,
#   47209,
#   24964,
#   41665,
#   34401,
#   42701,
#   45007,
#   33401,
#   43789,
#   32433,
#   21903,
#   41787],
#  [16797, 39408, 25802, 21292, 12341, 43352],
#  [37687, 25670, 27307, 13176, 21709, 459, 23383, 47792, 47209, 38647, 11980],
#  [27596,
#   37464,
#   27344,
#   21267,
#   21841,
#   6615,
#   18441,
#   5337,
#   43713,
#   13176,
#   16349,
#   46346,
#   45957,
#   25588,
#   32850,
#   4421,
#   1376,
#   23516,
#   39619,
#   11644,
#   30336,
#   24009],
#  [47672, 30233, 11777, 27511, 44142, 11512],
#  [42004,
#   24852,
#   3529,
#   33827,
#   14421,
#   39647,
#   25918,
#   5025,
#   215,
#   20370,
#   42964,
#   39097,
#   20815,
#   43568,
#   19389],
#  [24852, 18523, 22124, 26604, 29487, 9076, 20754, 49520, 32747],
#  [49175,
#   6292,
#   40054,
#   14764,
#   6210,
#   7010,
#   25659,
#   48104,
#   34126,
#   17794,
#   46667,
#   35595,
#   18918,
#   21195],
#  [20995, 19677, 21108, 20899, 34243, 16823],
#  [1729],
#  [581,
#   24852,
#   25890,
#   26620,
#   41220,
#   35221,
#   26209,
#   35939,
#   28842,
#   24184,
#   46979,
#   21903,
#   43295,
#   42342,
#   32398,
#   1483],
#  [16939,
#   45064,
#   11154,
#   9605,
#   6187,
#   27801,
#   22620,
#   40002,
#   18987,
#   28473,
#   15359,
#   27243,
#   42620,
#   2525,
#   15417,
#   3518,
#   40424,
#   29196,
#   16185],
#  [30639, 27817],
#  [30450, 4149, 17207, 22610, 6793],
#  [31964, 34276, 1891, 31510, 36737, 6606],
#  [34824, 24964, 35939, 7456, 41920, 47209, 26769, 9327, 6020],
#  [2855, 28204, 17666, 27344, 27690, 40229, 46584],
#  [13221,
#   19678,
#   31995,
#   25718,
#   6948,
#   20280,
#   48720,
#   24964,
#   26800,
#   31506,
#   20015,
#   35815],
#  [24852,
#   6278,
#   14159,
#   42538,
#   29615,
#   44042,
#   12782,
#   7241,
#   24504,
#   6052,
#   25830,
#   42736,
#   5884,
#   25804,
#   47185,
#   12807,
#   26767,
#   39910],
#  [31651, 27839],
#  [33290,
#   26499,
#   18465,
#   11068,
#   16185,
#   21681,
#   16797,
#   45066,
#   22825,
#   47209,
#   16466,
#   40982,
#   46352,
#   38533,
#   34427,
#   49235],
#  [47209,
#   26209,
#   8518,
#   35939,
#   34969,
#   34358,
#   31717,
#   47719,
#   5514,
#   27966,
#   37646,
#   22113,
#   44632,
#   432,
#   16797,
#   31683,
#   39275,
#   20995],
#  [5102, 35383, 43461, 41277, 3039, 13194, 29698, 5199, 29881, 4210],
#  [46822],
#  [37993,
#   47083,
#   18201,
#   204,
#   45664,
#   23782,
#   36545,
#   19366,
#   22031,
#   48885,
#   5251,
#   19445,
#   8136],
#  [13176, 28204, 8277, 48110, 47209],
#  [27690,
#   13176,
#   28054,
#   5077,
#   27464,
#   10749,
#   49235,
#   22582,
#   15950,
#   43768,
#   21137,
#   28204,
#   43122,
#   21938,
#   21903,
#   27156,
#   4487,
#   12597,
#   5994,
#   46979,
#   31927,
#   13829,
#   14553,
#   47759,
#   49267,
#   8193,
#   47626,
#   25005,
#   22935,
#   44359,
#   22849,
#   11992,
#   37029,
#   46993,
#   22720,
#   13280],
#  [35951,
#   47626,
#   17795,
#   36695,
#   27104,
#   22935,
#   34243,
#   25272,
#   35163,
#   42768,
#   25931,
#   30975,
#   12113,
#   5025,
#   14704],
#  [41290, 27845, 44560, 13838, 24411, 29662, 19057, 13802, 6873, 43768, 36695],
#  [4781,
#   18656,
#   29675,
#   13780,
#   5769,
#   22935,
#   9036,
#   45066,
#   30290,
#   16145,
#   20316,
#   7485,
#   17200,
#   12409,
#   20957,
#   39971,
#   43086,
#   42265],
#  [23288,
#   14399,
#   8193,
#   24846,
#   3631,
#   4781,
#   9028,
#   46616,
#   36070,
#   46372,
#   8424,
#   13176,
#   29307],
#  [8021, 19990, 32689, 33731, 23115, 32869],
#  [47402],
#  [5782,
#   32211,
#   45064,
#   2525,
#   12606,
#   42147,
#   6128,
#   45938,
#   940,
#   42184,
#   41523,
#   26209,
#   22282,
#   44224],
#  [23909,
#   1376,
#   46331,
#   21137,
#   27548,
#   21949,
#   38374,
#   45541,
#   3667,
#   4486,
#   20039,
#   40329,
#   27307,
#   21616,
#   45200,
#   9472],
#  [48665,
#   35378,
#   9387,
#   17794,
#   9824,
#   1281,
#   43329,
#   8747,
#   49203,
#   45656,
#   32030,
#   13544],
#  [17872, 39732, 40031, 47766, 27845, 44765, 4421, 35951, 9385],
#  [8056, 11520, 2480, 22825, 36913, 41340, 2269, 16501, 33946, 39013],
#  [22952, 10504, 35042, 38230, 46720, 12382, 26318, 2918, 15333, 32655],
#  [7862, 13097],
#  [28442, 19624, 48519, 26209, 49605, 3947],
#  [21162, 18176, 22935, 25659, 18434, 24964, 4855, 39877, 19678, 11112],
#  [29987, 32812, 21019, 24852],
#  [21195,
#   10258,
#   7751,
#   17862,
#   17902,
#   43371,
#   43692,
#   42475,
#   11759,
#   12271,
#   13535,
#   21292,
#   8571,
#   12732],
#  [18673, 14519, 20747, 42677, 47657, 16170, 43502, 32300, 39891],
#  [24852, 28204, 4920, 46906, 38383, 26209, 31717, 10017],
#  [26165,
#   39108,
#   34448,
#   38739,
#   7043,
#   11352,
#   3382,
#   34065,
#   43713,
#   49533,
#   8025,
#   878,
#   27735,
#   9424,
#   895,
#   37067,
#   18135,
#   23537],
#  [14074,
#   48925,
#   15366,
#   12004,
#   38837,
#   34939,
#   47766,
#   23634,
#   29487,
#   31612,
#   32734,
#   26751,
#   5640,
#   13870,
#   31258,
#   23094,
#   42265,
#   20119,
#   16848,
#   20995,
#   36149,
#   41844,
#   45788,
#   16174,
#   13712,
#   28123,
#   37766,
#   7969,
#   2086,
#   19468,
#   8021,
#   20580,
#   1618,
#   46206,
#   19057,
#   23125,
#   8774,
#   34217,
#   21002,
#   46979,
#   5994,
#   26010,
#   16710,
#   48957],
#  [20738, 24852, 5991, 14467],
#  [22882,
#   27966,
#   32566,
#   32239,
#   26209,
#   3308,
#   18523,
#   14999,
#   21883,
#   47141,
#   41273,
#   9387,
#   5068,
#   46572,
#   47862,
#   39646],
#  [22935, 5450, 18479],
#  [36070,
#   49683,
#   33846,
#   27435,
#   42633,
#   9387,
#   47626,
#   30756,
#   43295,
#   16797,
#   11777,
#   14320,
#   22129,
#   48123,
#   16325,
#   31553,
#   34126,
#   2966,
#   45116,
#   18891,
#   41058,
#   43530,
#   12548,
#   6631],
#  [39993, 28601, 6719, 14705, 41238],
#  [47209,
#   26209,
#   29315,
#   32156,
#   39351,
#   37320,
#   11821,
#   723,
#   46175,
#   25745,
#   6414,
#   15638,
#   22717,
#   39620,
#   47962,
#   32133,
#   1138,
#   10321,
#   21781,
#   44925,
#   38407,
#   1313,
#   19068,
#   41065,
#   19048,
#   37646,
#   47626,
#   38889,
#   40997],
#  [42536,
#   26949,
#   47766,
#   21137,
#   39275,
#   12932,
#   43961,
#   16848,
#   47059,
#   47222,
#   40396,
#   40709,
#   36397],
#  [36051],
#  [432,
#   24852,
#   28842,
#   26209,
#   27086,
#   5025,
#   20114,
#   3896,
#   32429,
#   22210,
#   22969,
#   36085,
#   13025,
#   16508,
#   27521,
#   21162,
#   4605,
#   37221,
#   44683,
#   5818,
#   10199,
#   40078,
#   9006,
#   10644,
#   27913,
#   38984,
#   22591],
#  [27104, 28204, 18232, 18200, 47823],
#  [12614, 47766, 35939, 45763, 16617, 37664, 34429, 41578, 43262, 2966],
#  [32734,
#   33731,
#   48352,
#   30489,
#   49683,
#   9698,
#   6489,
#   5517,
#   47059,
#   40878,
#   32433,
#   5959,
#   39408,
#   8174,
#   248,
#   14739,
#   7413,
#   3661,
#   24518,
#   13425],
#  [21616, 28986],
#  [8903, 24238, 32569, 39276, 48527, 35989, 35221],
#  [14084, 40174, 44632, 24561, 16254, 44422, 37257, 44728, 46812],
#  [8193, 10814, 40585, 16185, 5337, 19415, 17835, 35838],
#  [11422, 14233, 6182, 27966, 27845, 13245],
#  [8467, 24852, 9515, 28204, 48205],
#  [11408, 18918, 29987, 32655, 2962],
#  [34407, 26497],
#  [13755, 37940, 17965, 49144, 10145, 12333, 15905],
#  [5393, 9020, 46171, 28755, 38289, 27817, 41658],
#  [40261, 20119, 33791, 24852, 21472, 35199, 43967, 40332],
#  [27323, 40600, 13536, 1581, 28647],
#  [33240,
#   508,
#   15177,
#   8639,
#   14089,
#   16766,
#   38164,
#   36216,
#   2611,
#   32647,
#   39468,
#   31693,
#   8912,
#   12492,
#   28851,
#   28535,
#   13176,
#   34197,
#   3840,
#   39275],
#  [40469, 5067, 34921, 32562, 6265, 47758, 17675],
#  [12341, 20776, 16797],
#  [9558, 23296, 33548, 23106, 44156, 46817],
#  [10060, 13176, 1463, 22035, 34230, 8670, 22935, 10436, 3952],
#  [13176, 26915, 47209, 37646, 10912, 22211, 27966, 21777, 48610, 1373, 32352],
#  [45066, 9036, 5876, 26209, 43122, 24838, 41565],
#  [6195, 22025, 6825, 46676, 15030, 21709],
#  [44422,
#   45965,
#   29447,
#   24706,
#   48491,
#   16797,
#   32139,
#   21903,
#   12597,
#   15630,
#   47766,
#   42701,
#   11250,
#   6348,
#   44632,
#   11193,
#   36076,
#   22025,
#   17835,
#   39877,
#   7041,
#   42625],
#  [35221,
#   44632,
#   13176,
#   43961,
#   5973,
#   12686,
#   13380,
#   27737,
#   28458,
#   23148,
#   34217,
#   24195,
#   6669,
#   25762,
#   4697,
#   2999],
#  [1940,
#   24852,
#   24024,
#   21137,
#   27966,
#   19173,
#   26604,
#   28928,
#   19057,
#   14858,
#   22035,
#   49273,
#   26283,
#   45,
#   5450,
#   20015,
#   33731,
#   25093,
#   14992,
#   40706,
#   8424,
#   21903,
#   48595,
#   24489],
#  [27730,
#   40001,
#   46069,
#   11140,
#   30494,
#   43988,
#   41860,
#   30489,
#   32486,
#   45123,
#   7821,
#   9438],
#  [18860, 8153, 41131],
#  [742, 14992, 17461],
#  [20940, 16797, 12341, 21288, 20955, 25133, 8048, 32455, 21292, 43352, 46931],
#  [19450, 26620, 5456, 46650, 22935, 24964],
#  [21903, 34969, 13517, 17795, 24852],
#  [43295,
#   13176,
#   23579,
#   20693,
#   20113,
#   18352,
#   7963,
#   27344,
#   35163,
#   33000,
#   3884,
#   27966,
#   34335,
#   36702,
#   42508],
#  [38672, 24749, 11827, 45296, 196, 23888, 32428],
#  [24024, 39468, 15290, 39643, 22935, 21938, 21137, 47209],
#  [19894,
#   2237,
#   6628,
#   49533,
#   5025,
#   15392,
#   19678,
#   22935,
#   14540,
#   17316,
#   34358,
#   5077,
#   23130,
#   21560,
#   2994,
#   35678,
#   26242,
#   3098,
#   12442,
#   33290],
#  [4724, 16283, 30827, 8048, 37687],
#  [32768,
#   24852,
#   47626,
#   5818,
#   35042,
#   38379,
#   31506,
#   5025,
#   42625,
#   38797,
#   5744,
#   19691,
#   4853],
#  [8580, 9075, 44051, 1185, 659],
#  [13176, 34, 21903, 30406, 4799, 21850, 15937, 13031, 34358],
#  [11520, 31459, 4579, 29139, 38400, 16757, 34190, 38557],
#  [26604, 43352, 13176],
#  [40396],
#  [18465, 13176, 21137, 6187],
#  [47209, 34214, 5449, 7131],
#  [38567,
#   2825,
#   20011,
#   40706,
#   29722,
#   35561,
#   41066,
#   11807,
#   644,
#   38618,
#   41437,
#   46069,
#   44471,
#   13176,
#   35168],
#  [45, 24852, 20774, 16397, 7925, 34407, 32784, 19800, 11461, 29553],
#  [47766, 42585, 39013, 45007, 13176, 38609, 17794, 8193],
#  [21137, 45066],
#  [16521, 27086, 39180, 43192, 24846, 16262, 35383, 22537, 19451],
#  [13874, 40723, 48637, 41570, 23537, 43920, 22627, 21137, 17038, 19660],
#  [32611,
#   31130,
#   13292,
#   30489,
#   17706,
#   26209,
#   34126,
#   24852,
#   41950,
#   10251,
#   25340,
#   1862,
#   46676,
#   2344,
#   25837,
#   35939,
#   24184,
#   30391,
#   45200,
#   31444],
#  [38689, 25133, 18234],
#  [7926, 38051, 1938, 38689, 34993, 17183],
#  [5025, 3631, 47503, 48679, 22900, 31506, 21616, 27930, 47630, 40706],
#  [38241,
#   33548,
#   46817,
#   9387,
#   12302,
#   47977,
#   36316,
#   1831,
#   27275,
#   32553,
#   23085,
#   30353,
#   1940,
#   22489,
#   46041,
#   12191,
#   1752,
#   33397],
#  [35147,
#   49235,
#   15074,
#   13852,
#   6765,
#   12980,
#   37825,
#   21903,
#   35939,
#   24799,
#   8309,
#   17461,
#   41593],
#  [46785, 40897, 22182, 44799],
#  [41844,
#   43263,
#   40212,
#   31433,
#   37066,
#   33819,
#   16464,
#   6348,
#   36058,
#   33351,
#   1069,
#   26040,
#   27730,
#   24852,
#   10492,
#   40338,
#   18811,
#   17872,
#   32299,
#   43076,
#   28384,
#   4006,
#   4656,
#   16953,
#   35909],
#  [3957, 25371],
#  [32911, 17429, 1359, 46962, 38903],
#  [46665, 33198, 48857, 42817],
#  [47766, 8277, 21903, 41220, 21137, 44819],
#  [43379],
#  [29642, 31500, 19189, 35315, 45004],
#  [2078, 5785, 7781, 6297, 23375, 19057, 36724, 18370],
#  [1511, 33120, 21137, 9076, 21955, 41844, 19057],
#  [39947, 44632, 5876, 18918, 24489, 21828, 4461, 31338, 44120],
#  [35951,
#   39190,
#   48846,
#   13740,
#   5194,
#   47521,
#   24852,
#   22220,
#   24157,
#   12154,
#   38527,
#   24841,
#   41793,
#   46229,
#   17974,
#   36537,
#   38256,
#   2067,
#   19115,
#   25340,
#   28204,
#   35708,
#   47717,
#   10551,
#   14627,
#   39322],
#  [5067, 32478],
#  [11365, 16797, 43352],
#  [14650, 21543, 13176, 8667],
#  [27323, 7819, 7644],
#  [26768,
#   35734,
#   7401,
#   13212,
#   43295,
#   35921,
#   28769,
#   5025,
#   95,
#   31506,
#   21903,
#   19057,
#   39928,
#   24852,
#   1999,
#   24964,
#   17794,
#   28842,
#   18479,
#   45007,
#   40706,
#   17948,
#   2094],
#  [34668, 17487],
#  [2716,
#   45210,
#   48726,
#   48946,
#   44632,
#   21709,
#   37276,
#   44165,
#   12033,
#   31126,
#   43165,
#   28353,
#   22164,
#   25948,
#   31886,
#   38164,
#   3398,
#   13898,
#   33716,
#   35708,
#   7139,
#   46616,
#   29077,
#   23017,
#   34668,
#   29607,
#   1463,
#   27086,
#   27247,
#   25225,
#   47621],
#  [43221,
#   7017,
#   3374,
#   22556,
#   10619,
#   5782,
#   27578,
#   44594,
#   30889,
#   43772,
#   44487,
#   49060,
#   10851,
#   37619],
#  [20448],
#  [4142,
#   30985,
#   24891,
#   44389,
#   4586,
#   23375,
#   20082,
#   26209,
#   36651,
#   31553,
#   4421,
#   12456,
#   2452,
#   17789,
#   3628,
#   22369,
#   25499,
#   37975,
#   48554,
#   42069,
#   26790,
#   47167,
#   31504,
#   4812,
#   21162,
#   34745,
#   31657,
#   46352,
#   43788,
#   40982,
#   12591,
#   16466,
#   21806,
#   11212,
#   44557,
#   436],
#  [8048, 22507],
#  [24852, 43662, 8309, 30489, 8277, 28465, 30795, 47630],
#  [4091, 33452, 37011, 5268],
#  [6948, 22035, 8467, 28427, 17419, 2855, 5876, 40724],
#  [10032, 31981, 32141, 129],
#  [14992, 38689, 16185, 47766, 42828, 29574, 41787, 47788, 46979, 47626],
#  [29616, 46853],
#  [8859,
#   37158,
#   13176,
#   30489,
#   36397,
#   40063,
#   27554,
#   21162,
#   7781,
#   39877,
#   3818,
#   39475,
#   5902,
#   31343,
#   13838,
#   14084,
#   35461,
#   30277,
#   40632,
#   24928,
#   31634,
#   42536,
#   19046,
#   5134,
#   5785,
#   5876,
#   21137,
#   49215,
#   26317],
#  [21903, 21616, 47144],
#  [14992,
#   37646,
#   24221,
#   24390,
#   21938,
#   34969,
#   22170,
#   27104,
#   13629,
#   7519,
#   38837,
#   44612],
#  [46802, 24852, 27521, 22276, 6287, 48017, 24964, 17794],
#  [38544, 47209, 24852, 42356, 14867, 27573, 48182, 17021, 25824, 42265],
#  [24489,
#   25890,
#   41220,
#   44142,
#   28204,
#   30489,
#   43961,
#   27730,
#   24852,
#   19449,
#   42828,
#   34969,
#   39561,
#   3682],
#  [21137,
#   31915,
#   35503,
#   6948,
#   18418,
#   34012,
#   12941,
#   19272,
#   24253,
#   47166,
#   7773,
#   18814,
#   14947],
#  [24097, 45211, 6348, 38016, 32627, 9172, 39264, 12962],
#  [43129,
#   31506,
#   36011,
#   24852,
#   21267,
#   24964,
#   43768,
#   5373,
#   8671,
#   7175,
#   5746,
#   14992,
#   46667,
#   42736],
#  [32851,
#   37238,
#   44142,
#   33065,
#   4297,
#   33827,
#   17795,
#   13553,
#   7901,
#   4933,
#   32299,
#   21019],
#  [40706, 48205, 18564, 35221],
#  [26348, 21572, 6184, 32455, 11759, 769],
#  [9070, 46321, 46087, 39928, 37496],
#  [2579,
#   9739,
#   24964,
#   6182,
#   28928,
#   30639,
#   23695,
#   34824,
#   44008,
#   39560,
#   9038,
#   47209,
#   2081,
#   17745,
#   8022,
#   44698,
#   18090,
#   8518,
#   47734,
#   15261,
#   34012,
#   46720,
#   18880,
#   32689,
#   19154],
#  [47977, 49520, 45190, 31377],
#  [19966, 38834, 9124, 28431, 22035, 47119, 6459, 4392],
#  [32110, 39468, 35420, 13176, 46979, 27177, 21903, 11688, 11193, 27695, 22950],
#  [13176, 35221, 27030, 45633, 19057, 2391, 26369, 20738, 11030, 11576, 27344],
#  [44116,
#   47766,
#   33198,
#   39041,
#   29921,
#   42625,
#   24850,
#   7615,
#   32023,
#   38395,
#   26698,
#   11568,
#   1138,
#   15937,
#   10092,
#   35970,
#   48705,
#   6177,
#   20578,
#   38044,
#   38236,
#   17328,
#   36695,
#   27796,
#   13834],
#  [39275, 651, 7862],
#  [42959, 21841, 3510, 42460, 17708, 24649, 22963, 10851, 43583, 37203, 20590],
#  [20842,
#   10163,
#   45866,
#   10749,
#   35958,
#   18670,
#   10724,
#   26209,
#   29801,
#   48464,
#   17948,
#   27966,
#   33055,
#   13380,
#   8848,
#   35163,
#   10337,
#   42265,
#   44359,
#   8174,
#   38456,
#   1819,
#   46281,
#   26604,
#   21405],
#  [20561, 41844, 14168, 12945, 20467, 46175, 34534, 38341],
#  [37886, 38763, 37096, 12260, 38067, 39365, 27398],
#  [2210, 13176, 10070, 32689, 39928, 24184, 19816, 19019, 22963],
#  [21903,
#   9076,
#   28985,
#   29142,
#   17872,
#   25890,
#   33120,
#   21543,
#   26128,
#   24082,
#   34584,
#   39275,
#   47492,
#   45,
#   22124,
#   4957,
#   33787,
#   33754,
#   31663,
#   1540,
#   39430,
#   47626],
#  [5785, 40910, 11039, 40571, 31907, 18616, 12916, 4605, 2064, 31236, 27086],
#  [46346,
#   39180,
#   30849,
#   17833,
#   24852,
#   37524,
#   47209,
#   22713,
#   28993,
#   40604,
#   248,
#   7762,
#   42828,
#   47144,
#   25199,
#   4656,
#   32839,
#   10912,
#   34622,
#   33606,
#   13535,
#   23734],
#  [34459, 35234, 3880, 712, 47114, 3847, 16797, 25461],
#  [31338, 9608, 49610, 27744, 35951, 47229, 24852, 14161, 5450, 41787],
#  [9766, 46709, 46900, 8230, 7700, 19731],
#  [25890,
#   44424,
#   28985,
#   21903,
#   29662,
#   13802,
#   21280,
#   18441,
#   10960,
#   24852,
#   25659,
#   24952,
#   46979],
#  [37646, 3952, 25466, 14233],
#  [22935],
#  [20383,
#   30909,
#   40709,
#   6489,
#   46802,
#   1158,
#   24838,
#   14579,
#   28156,
#   27325,
#   9047,
#   16528],
#  [45788,
#   24852,
#   48697,
#   31506,
#   49416,
#   23288,
#   12409,
#   16521,
#   7054,
#   16797,
#   42768,
#   26751],
#  [6813, 432, 36955, 40332, 2966, 34640, 14197, 8670, 43565, 9076],
#  [13176,
#   27413,
#   24288,
#   27966,
#   5876,
#   48219,
#   20734,
#   31504,
#   1890,
#   2078,
#   37866,
#   44233,
#   49044,
#   21295,
#   43768,
#   2099,
#   24129,
#   41064,
#   41620,
#   23734,
#   16291,
#   17160,
#   4812,
#   12254,
#   28050],
#  [30027, 44144, 22713, 40852, 19508, 8996, 4476, 24184, 26209, 15591],
#  [13544, 20995, 15325, 14668, 21137, 40706],
#  [44829, 21137, 37288, 37141, 4942, 5303, 36724, 38159, 260],
#  [31263, 49683, 23785, 48205, 26604, 16797, 13834, 32360, 24637, 260, 11456],
#  [1408, 40338, 17601, 21288, 8424, 32330, 11869],
#  [18637, 47946, 939, 27178, 22340, 46616, 11996, 29689, 33990, 8324, 2144],
#  [5077,
#   49131,
#   18465,
#   9808,
#   31766,
#   17630,
#   39275,
#   895,
#   39578,
#   33787,
#   4957,
#   26790,
#   45066,
#   1896,
#   42265,
#   30489,
#   36256,
#   22825,
#   25072,
#   25890,
#   14643,
#   9339,
#   17200,
#   5785,
#   42383],
#  [14992,
#   47766,
#   24852,
#   10831,
#   27845,
#   31371,
#   45763,
#   45066,
#   25890,
#   5479,
#   16797,
#   2611,
#   162,
#   22035,
#   39877],
#  [22298,
#   5550,
#   1819,
#   13176,
#   28199,
#   21847,
#   48437,
#   37220,
#   2581,
#   21543,
#   22963,
#   39781,
#   12258,
#   40174,
#   30839,
#   41844,
#   9871,
#   48775,
#   651,
#   21903,
#   39275,
#   5130,
#   43768,
#   42265,
#   41658,
#   33316,
#   47209,
#   22825,
#   44560],
#  [9337, 26675],
#  [13176, 43122, 8277, 33768, 19048, 22935, 15290, 8193, 2361, 47388, 48205],
#  [34165, 39719, 46138, 46251],
#  [44949,
#   9839,
#   12357,
#   24852,
#   33120,
#   32360,
#   45,
#   39984,
#   38273,
#   35887,
#   48094,
#   15074,
#   42307,
#   41220,
#   22035,
#   11790,
#   3098,
# ...
#   27156,
#   2002,
#   43392,
#   42016,
#   9472,
#   45007,
#   141,
#   4376,
#   21137],
#  [22525, 32403, 16797, 7930, 28632, 6568, 39844, 42240, 17304, 15807],
#  [4461,
#   9755,
#   46855,
#   42450,
#   16185,
#   39134,
#   17484,
#   30994,
#   47154,
#   33000,
#   34927,
#   34530,
#   13289,
#   17948],
#  [23634, 46802, 1158, 44372, 8809, 49683],
#  [35914,
#   287,
#   17295,
#   13176,
#   25976,
#   15872,
#   365,
#   27360,
#   21616,
#   43772,
#   36552,
#   34605],
#  [47485, 22935, 20869, 18479, 13291, 5373, 31506, 21137, 45007, 25890, 47626],
#  [34986, 28199, 13870, 43772, 18019, 20955, 33095],
#  [34126, 31159, 36011, 8506],
#  [13176, 21137, 20995, 43352, 38176],
#  [29406, 28715, 23375, 25890, 22935, 6615, 35199, 8193, 19019, 39322, 1215],
#  [11365, 12341, 21137, 26759],
#  [1335, 14965, 14394, 44787, 14693, 29156, 19248, 16697, 8186, 25544],
#  [47209,
#   17672,
#   39276,
#   28725,
#   4149,
#   33000,
#   6774,
#   43154,
#   43961,
#   22952,
#   18531,
#   24170,
#   31444,
#   31640,
#   33548,
#   23296,
#   33791,
#   46817,
#   42372,
#   44156],
#  [46979,
#   8518,
#   21070,
#   4605,
#   35973,
#   2380,
#   38293,
#   7021,
#   49175,
#   28535,
#   31717,
#   20114],
#  [33731, 39180, 19478, 7948, 17652, 7500, 13852],
#  [14084, 49075, 40268, 2825, 30450, 46303, 46087, 14896],
#  [34126,
#   34969,
#   43789,
#   39812,
#   3464,
#   23643,
#   260,
#   21938,
#   46979,
#   21405,
#   30720,
#   27336,
#   2643,
#   13176],
#  [26620, 30353, 28342, 25146, 24382, 27344],
#  [10509, 39275, 27966],
#  [39275, 27845, 19286, 34551, 196],
#  [25305,
#   8277,
#   47209,
#   18205,
#   23178,
#   42701,
#   38647,
#   33000,
#   44825,
#   15740,
#   5479,
#   27086,
#   7963,
#   45007,
#   26369],
#  [23280, 32566, 5918, 6631, 24425, 6193, 44175, 40486, 44042],
#  [43086,
#   49683,
#   1511,
#   2855,
#   12745,
#   10768,
#   31288,
#   17553,
#   4451,
#   8490,
#   49628,
#   47626,
#   18362,
#   3896,
#   22559,
#   49235,
#   4920],
#  [45504, 41844, 24852, 31506, 31066, 13885],
#  [32486, 21903, 25890, 10343, 11140, 23339],
#  [24852, 11512, 21903, 29574, 28622, 45913, 13431, 11352, 4656, 2350],
#  [24852,
#   40198,
#   39411,
#   35221,
#   31215,
#   34993,
#   22151,
#   28204,
#   40763,
#   25043,
#   38164,
#   37276,
#   32523,
#   31886,
#   13577,
#   22164,
#   47621,
#   31444],
#  [3896, 38689, 13176, 6000, 29126, 1374, 37646, 43122, 47105, 21009, 43713],
#  [6265,
#   9387,
#   47766,
#   29127,
#   24852,
#   46656,
#   19348,
#   33894,
#   46323,
#   27044,
#   5128,
#   47555,
#   30583,
#   36259,
#   14161],
#  [25745,
#   40711,
#   25814,
#   41068,
#   4373,
#   32338,
#   18523,
#   42372,
#   47766,
#   16900,
#   36956,
#   6475,
#   26209,
#   28836,
#   14420,
#   2120,
#   44479,
#   722,
#   20539,
#   45325],
#  [27360, 39800, 11463],
#  [40216, 34969, 5025, 47766, 44570, 42483, 43513, 5818],
#  [48110, 39040, 44632, 39409, 11408],
#  [14992,
#   24852,
#   18234,
#   47734,
#   8193,
#   27104,
#   5077,
#   4210,
#   44008,
#   23537,
#   8087,
#   31717,
#   31915,
#   19106],
#  [46979, 42736, 46676, 43504, 34281, 37687, 27662],
#  [38777,
#   34,
#   8087,
#   2350,
#   46738,
#   16083,
#   24852,
#   22825,
#   27845,
#   8518,
#   28590,
#   28204,
#   8424],
#  [21137, 10017],
#  [9020,
#   7600,
#   16953,
#   28913,
#   31553,
#   26209,
#   31717,
#   4966,
#   44632,
#   35221,
#   11361,
#   13909,
#   34358,
#   47626,
#   19653,
#   39408],
#  [26093,
#   10172,
#   13176,
#   44359,
#   35935,
#   5547,
#   28985,
#   15872,
#   39299,
#   11744,
#   22760,
#   27104,
#   12474,
#   4329],
#  [4781,
#   24279,
#   33120,
#   40009,
#   45210,
#   35851,
#   42736,
#   6274,
#   5025,
#   37067,
#   39877,
#   39799,
#   44910,
#   39739],
#  [10036, 35842, 16349, 28594, 34134, 3020, 39275],
#  [40604, 42768, 27156, 24184, 17794, 3376, 4210, 31553, 24964, 26209, 49683],
#  [19781, 260, 47144],
#  [27845,
#   13176,
#   19057,
#   17706,
#   8277,
#   37646,
#   21137,
#   260,
#   5450,
#   36410,
#   22908,
#   7175,
#   42585,
#   18629,
#   24413,
#   12820,
#   32989,
#   38355,
#   12020,
#   28745,
#   4097],
#  [21658, 47141],
#  [19660, 17207],
#  [5031, 3849, 13176, 25824, 24489, 30233],
#  [3765,
#   27360,
#   19173,
#   2469,
#   29931,
#   24852,
#   39582,
#   6047,
#   12916,
#   24759,
#   27985,
#   49030,
#   33452,
#   1986,
#   32829,
#   36403,
#   28191,
#   3885,
#   29553],
#  [32981, 32931, 30459, 43891, 25653, 41064, 19457, 19822, 20084, 26882, 40706],
#  [42701,
#   37646,
#   35628,
#   12644,
#   41950,
#   47766,
#   9755,
#   46969,
#   169,
#   14901,
#   46709,
#   18352,
#   26177,
#   46993,
#   42205,
#   15392,
#   24852,
#   48679],
#  [42495, 18339, 22825, 31915, 1364, 19348, 4210, 24852, 26419, 15981],
#  [44359, 23622, 32134, 4920],
#  [3661, 25824, 40571, 33043, 9743, 43295, 26317, 5013, 38471, 29328, 42460],
#  [4313,
#   37152,
#   36107,
#   26689,
#   23082,
#   23909,
#   43129,
#   8069,
#   25170,
#   10386,
#   7400,
#   30950,
#   13636,
#   17872,
#   30668,
#   4478,
#   7789,
#   28384],
#  [22557,
#   24891,
#   46567,
#   38944,
#   17600,
#   28156,
#   14697,
#   44116,
#   33219,
#   23216,
#   28281,
#   11256],
#  [6182, 35233, 9387, 43122, 31553, 14462],
#  [21295, 13280, 47672, 33953, 33731, 27104, 26620],
#  [30776,
#   5514,
#   32134,
#   8518,
#   30391,
#   19511,
#   31683,
#   8424,
#   28289,
#   48679,
#   46979,
#   46667,
#   24964,
#   12614,
#   12779,
#   39275,
#   39190,
#   39619],
#  [31268, 39945, 11947, 33351, 24852, 24392, 31506, 14895],
#  [38384, 8490, 24852, 47498, 5612, 42356, 457, 23516, 15349, 21927, 35176],
#  [49185,
#   33148,
#   18564,
#   26620,
#   12932,
#   46346,
#   28204,
#   29307,
#   23375,
#   47804,
#   30776,
#   3761,
#   49683],
#  [33037,
#   44422,
#   16977,
#   38456,
#   4855,
#   27521,
#   5876,
#   17419,
#   23044,
#   13935,
#   43122,
#   43961,
#   20431,
#   45007,
#   30720,
#   10351,
#   39928,
#   4920,
#   25340,
#   8424,
#   28985,
#   4605,
#   5184],
#  [36472, 46061, 46149],
#  [39758,
#   10737,
#   7644,
#   17733,
#   47766,
#   49683,
#   24604,
#   4731,
#   29487,
#   26604,
#   26040,
#   15242,
#   27924,
#   21472,
#   28204,
#   39877,
#   38456,
#   13176,
#   26425,
#   36393,
#   23341,
#   1582,
#   48505,
#   43886,
#   1094,
#   11392,
#   29646,
#   19813,
#   16920,
#   43352,
#   4006],
#  [43712, 19938, 1819, 38012, 33000, 15613, 48364],
#  [13431, 26706, 4605],
#  [19675],
#  [32655, 29447, 49383, 38557, 33055],
#  [44632, 28849, 48094, 5818, 24964, 47209, 38557, 31927, 33731, 38293, 42265],
#  [48192, 4210, 39321, 27398, 15109, 19620, 16953, 994, 43354],
#  [33279, 39399, 37250],
#  [18709, 54, 24852, 23670, 21435, 36848, 19677, 5250, 47792, 12324, 34446],
#  [17858, 47977, 35914, 37262, 32265, 45698, 43279],
#  [22475,
#   39620,
#   27429,
#   24114,
#   29487,
#   29142,
#   23046,
#   8262,
#   22497,
#   29912,
#   24852,
#   2103,
#   28199,
#   9387,
#   35855,
#   39993,
#   48871,
#   41729,
#   40332],
#  [39619,
#   21622,
#   30450,
#   48679,
#   43735,
#   40531,
#   36695,
#   8193,
#   13176,
#   20842,
#   13198,
#   47209,
#   43352,
#   21137,
#   43889],
#  [30353, 39947, 12576],
#  [12020, 17600, 38544, 7781, 18609, 4321, 47209, 7615, 28535, 40706],
#  [1194, 35473, 42404, 32650, 39858],
#  [45636, 2677, 35121, 45603, 8736, 28613],
#  [24852,
#   26209,
#   7010,
#   40554,
#   24521,
#   41960,
#   20995,
#   1999,
#   5991,
#   5876,
#   21137,
#   19057,
#   25890,
#   34530,
#   3142,
#   21903,
#   12036,
#   48341,
#   27662,
#   27966,
#   43749],
#  [2180,
#   40553,
#   6242,
#   7158,
#   48205,
#   18709,
#   41619,
#   25397,
#   20239,
#   7660,
#   3400,
#   25495,
#   22906,
#   25461,
#   5876,
#   28990,
#   40866,
#   40310,
#   22105,
#   22424,
#   24257],
#  [5514, 11520, 12892, 18880, 18441, 36178],
#  [1529, 20734, 22935, 26728],
#  [45004, 32455],
#  [13646,
#   24852,
#   18689,
#   27521,
#   28785,
#   38312,
#   31635,
#   48220,
#   15984,
#   48415,
#   37053,
#   16145,
#   28204,
#   8670,
#   41950,
#   38108,
#   7806,
#   10749],
#  [29447,
#   24852,
#   27966,
#   38558,
#   14486,
#   22035,
#   3952,
#   781,
#   20431,
#   1446,
#   48726,
#   41593,
#   39002,
#   21614,
#   20528,
#   33342],
#  [30960,
#   47144,
#   47766,
#   5077,
#   27966,
#   25146,
#   47141,
#   9510,
#   31960,
#   13176,
#   17600,
#   41290,
#   25513,
#   39491,
#   28993,
#   43772,
#   21938,
#   29392,
#   28299,
#   21553],
#  [24852,
#   39747,
#   49235,
#   17224,
#   21137,
#   17949,
#   16262,
#   1577,
#   7026,
#   42828,
#   36076,
#   21150],
#  [13829, 33575, 28199, 401, 24768, 23543, 18441, 691],
#  [40396],
#  [42240, 588, 17678, 31808],
#  [29893,
#   41277,
#   10912,
#   3696,
#   29487,
#   38154,
#   37084,
#   33245,
#   13573,
#   9130,
#   48742,
#   3732,
#   31981,
#   1157,
#   48907,
#   4377,
#   24852,
#   9300,
#   7600,
#   32888],
#  [48697, 47345, 276, 20823, 18709, 24852, 47941, 39408, 31268],
#  [47626,
#   9020,
#   7461,
#   21616,
#   37687,
#   47766,
#   890,
#   33716,
#   2295,
#   4472,
#   23898,
#   16824,
#   21417],
#  [47144, 4920, 10872, 30996, 17073, 46093, 2228, 7014, 39984],
#  [13176,
#   1511,
#   5161,
#   24964,
#   19446,
#   8424,
#   15630,
#   20280,
#   16185,
#   2314,
#   44422,
#   43713,
#   43352,
#   14199,
#   18340,
#   5959,
#   14992,
#   22849,
#   21616,
#   30489,
#   21417,
#   21903,
#   38903,
#   42625,
#   30720],
#  [33984,
#   4889,
#   32864,
#   44799,
#   49010,
#   16419,
#   19076,
#   22359,
#   30633,
#   8424,
#   23909,
#   11461,
#   45296],
#  [19057,
#   41330,
#   39275,
#   25965,
#   30233,
#   26738,
#   26751,
#   38453,
#   22367,
#   32655,
#   42680,
#   42265],
#  [44061,
#   30849,
#   16797,
#   26604,
#   24852,
#   47766,
#   33548,
#   42598,
#   32331,
#   38799,
#   43814,
#   2067,
#   17631,
#   40787,
#   41844],
#  [27511, 13852, 28985],
#  [49044, 30192, 31504, 9808, 49215, 35376, 13874, 890, 21938, 16145],
#  [26620,
#   13176,
#   7781,
#   21137,
#   19348,
#   41844,
#   47626,
#   34969,
#   38988,
#   42265,
#   30489,
#   15592,
#   20345],
#  [47966,
#   45066,
#   7156,
#   40706,
#   36695,
#   21137,
#   29095,
#   24810,
#   21814,
#   42585,
#   39428,
#   24184,
#   8138,
#   5025,
#   17794,
#   44968,
#   21288,
#   31562,
#   42625,
#   7335,
#   28248,
#   9551,
#   30955,
#   34739,
#   13639,
#   21405],
#  [29650, 28289, 8297],
#  [13176, 21872, 41950, 13802, 16616],
#  [36639, 41319, 28836, 10793, 38097, 38290, 23619, 24852, 28226],
#  [24852,
#   14947,
#   42265,
#   38028,
#   26032,
#   18670,
#   21903,
#   42342,
#   49683,
#   47766,
#   39475,
#   25556,
#   48679,
#   16083,
#   37646,
#   34049,
#   28985,
#   46802,
#   9076,
#   1468,
#   21367,
#   812,
#   10017,
#   26497,
#   28127,
#   41463,
#   25936,
#   890,
#   28849,
#   42585,
#   38293,
#   44628,
#   44873,
#   41593,
#   1416,
#   45007,
#   8518,
#   20842,
#   18761],
#  [41276, 196, 46149, 16732, 35470],
#  [17484, 14643, 43858],
#  [1783, 41367, 4605, 43768, 22866, 6652, 23734],
#  [4781,
#   2846,
#   22247,
#   43789,
#   34126,
#   45007,
#   41065,
#   9839,
#   21137,
#   42479,
#   33731,
#   27521,
#   22849,
#   30391,
#   14874,
#   10749],
#  [11352, 23938, 3479, 19272, 39190, 38944, 14881, 21463],
#  [29500,
#   24852,
#   4793,
#   46485,
#   20733,
#   43768,
#   27845,
#   1244,
#   30489,
#   939,
#   26706,
#   23579,
#   35629,
#   38313,
#   14466,
#   43122,
#   36695,
#   47616,
#   5450,
#   6860,
#   39332,
#   43961,
#   1751,
#   38293,
#   14084],
#  [40174,
#   11980,
#   35342,
#   24954,
#   20561,
#   21573,
#   33358,
#   5902,
#   25837,
#   11440,
#   10132,
#   16797,
#   31693,
#   47185,
#   9932,
#   3820,
#   46692,
#   41949,
#   14159,
#   1006,
#   24713,
#   43867,
#   18171,
#   13815,
#   24852,
#   46724,
#   15097,
#   7781,
#   19799,
#   36002,
#   44359,
#   13870,
#   21614,
#   23630,
#   14502],
#  [41787,
#   26209,
#   27845,
#   47626,
#   38400,
#   35376,
#   43086,
#   22935,
#   11440,
#   30391,
#   21137,
#   5212,
#   35948,
#   24759,
#   23375],
#  [44422, 15987, 16521],
#  [32299, 21174, 47209],
#  [11520, 13176, 47209, 37646, 21230],
#  [24852, 49683, 32030, 48395, 34243, 14992, 47626],
#  [38368, 10326, 3265],
#  [5077, 39468, 8174, 30776, 9839, 16744, 39247, 27966, 13176, 4472],
#  [21195],
#  [39657,
#   16974,
#   12341,
#   6184,
#   13575,
#   9387,
#   47402,
#   37710,
#   10441,
#   16797,
#   43352,
#   49235,
#   3798,
#   46931,
#   32455,
#   42265,
#   41787,
#   21288,
#   25146],
#  [19348, 17334, 24231, 42450, 18208, 45099, 28682, 11740, 29487, 16759, 29848],
#  [29429, 43556, 43951, 23612, 27117, 3990, 10111, 45076, 32566, 21100, 3195],
#  [25170, 9996],
#  [37867, 49139, 40348, 11874, 38470, 24184, 18394, 31670, 7952, 41178, 11281],
#  [33642, 35734, 47209, 4461, 24489, 26604, 651, 36646, 35921, 13176, 5550],
#  [11520,
#   40516,
#   47766,
#   8518,
#   24964,
#   21938,
#   45007,
#   47626,
#   33198,
#   8414,
#   49517,
#   1194,
#   34969,
#   26751,
#   913,
#   12564,
#   29987,
#   4799,
#   38266,
#   34243,
#   4853,
#   4562,
#   40174,
#   42736,
#   35108],
#  [35221, 21288, 43352, 41787, 24852, 25890, 13198, 8424, 8193, 16797, 48679],
#  [31338, 43523, 16365, 5513, 14063, 34619, 35909],
#  [43122],
#  [37462, 45603, 36397, 21903, 1158, 4429],
#  [19436, 13176, 25890, 5451, 42719, 581, 46979, 42847, 36724, 17758],
#  [37152, 43619, 5445, 4289, 34423],
#  [20073, 34590, 35951, 3025, 35734, 26800, 8981],
#  [37001,
#   23081,
#   42479,
#   38312,
#   15984,
#   13176,
#   47209,
#   9839,
#   28985,
#   27521,
#   43713,
#   16744,
#   37220,
#   17830,
#   19261,
#   18465,
#   41220,
#   6873,
#   16759,
#   5876,
#   44359,
#   39877,
#   19057,
#   30391,
#   24838,
#   40706,
#   24964,
#   48775,
#   2450,
#   7381,
#   22935,
#   45007,
#   19048],
#  [37646, 27966, 13751, 15740, 8516, 11193, 26131, 8490, 13646, 27156, 49175],
#  [49618, 17948, 329, 21405, 40706, 21903, 30391],
#  [4193,
#   47209,
#   27845,
#   35951,
#   33120,
#   5825,
#   24489,
#   40516,
#   16525,
#   49533,
#   33407,
#   16521,
#   13083],
#  [47144, 9075, 4605, 1006, 24571, 19488, 32330, 20682, 29487, 25154, 47626],
#  [23044,
#   30489,
#   13176,
#   5785,
#   47059,
#   48628,
#   32747,
#   27086,
#   6046,
#   44359,
#   17794,
#   23165,
#   47766,
#   39984,
#   5373,
#   21616,
#   40706,
#   9092,
#   24964,
#   38557,
#   37388,
#   23734,
#   13500,
#   44910,
#   36695],
#  [210, 20070],
#  [21903,
#   41593,
#   49235,
#   45613,
#   5212,
#   11865,
#   14945,
#   26475,
#   14651,
#   45013,
#   13269,
#   47192,
#   10315,
#   12223,
#   13031,
#   49114,
#   45177,
#   21459,
#   37055,
#   13858,
#   10467,
#   23909,
#   16837,
#   32734],
#  [24852, 22035, 39928, 35503, 6104, 27845],
#  [21137, 32689, 19057, 44142, 14992],
#  [20622, 5876, 23565, 4367],
#  [45013,
#   28204,
#   40612,
#   21137,
#   47209,
#   17949,
#   22035,
#   48857,
#   24852,
#   41665,
#   47672,
#   35503,
#   32486,
#   8193,
#   26351,
#   24079,
#   22247,
#   42701,
#   17429,
#   23088,
#   38622,
#   12442,
#   4799,
#   21386,
#   46294,
#   33352],
#  [11422,
#   40877,
#   39649,
#   7177,
#   23614,
#   21949,
#   46817,
#   33791,
#   33548,
#   44156,
#   49520,
#   48626,
#   36011,
#   38241,
#   23296,
#   23106,
#   1940,
#   42598,
#   15343],
#  [49235,
#   42633,
#   18340,
#   40229,
#   34034,
#   45646,
#   47543,
#   31506,
#   23236,
#   8670,
#   7628,
#   40377,
#   8940],
#  [38152, 12916, 36126, 32175],
#  [31737,
#   24852,
#   14089,
#   781,
#   6193,
#   24841,
#   22035,
#   7948,
#   22935,
#   9038,
#   6835,
#   14651,
#   17706,
#   47626,
#   15649,
#   43713,
#   21009,
#   6210,
#   13196,
#   30480,
#   26104],
#  [37029, 5212, 28577, 35628, 5077, 43961, 21903, 41950, 47209, 3631, 6104],
#  [43295,
#   32566,
#   24852,
#   24838,
#   31578,
#   49520,
#   23410,
#   36316,
#   31964,
#   35731,
#   10895,
#   17785,
#   2657,
#   31618,
#   38944,
#   39225,
#   37055,
#   33614,
#   30696,
#   3269,
#   6342,
#   9783,
#   38766,
#   30052,
#   10690,
#   365,
#   6809,
#   34640],
#  [23226, 11456, 47438, 41290, 4146, 31066, 43534, 6350, 36390, 4338],
#  [18615, 19508],
#  [21903,
#   38689,
#   30391,
#   18670,
#   10761,
#   162,
#   24830,
#   36216,
#   19938,
#   12258,
#   10017,
#   48679,
#   38012,
#   14992,
#   31263,
#   47144],
#  [24852, 39578, 38313, 24253, 15803, 38622],
#  [6933,
#   26131,
#   47912,
#   3721,
#   8490,
#   13176,
#   44632,
#   2962,
#   21709,
#   31640,
#   33454,
#   49235,
#   20119,
#   24838,
#   2876,
#   26620,
#   42557,
#   43713,
#   2362,
#   9203,
#   14947,
#   5450],
#  [24852, 28985, 47626, 16797, 32971, 41480, 48871, 20378, 32446],
#  [28759, 19677, 4210, 45066, 4920, 47626, 9387, 41787],
#  [7751, 30784, 40396, 39409, 1919, 5127],
#  [24852, 6184, 45066, 4942, 23955, 26666, 43264, 28507],
#  [33623, 30489, 25931, 28465, 26131, 47144, 32927, 8239, 25640, 9076, 28553],
#  [25986,
#   6016,
#   30721,
#   25077,
#   39636,
#   196,
#   12832,
#   40261,
#   14265,
#   44635,
#   27407,
#   7644,
#   24382,
#   25550,
#   12727],
#  [29447, 48628, 17224, 46847, 21903, 21413],
#  [27966, 13176, 44275, 30391, 26364, 44926, 26369, 21903, 44765],
#  [16757,
#   5876,
#   26369,
#   47766,
#   3098,
#   5479,
#   47144,
#   24852,
#   44910,
#   26242,
#   33055,
#   10017],
#  [39812, 22880, 11777, 43295, 36865, 13263, 47209],
#  [22507, 17313, 30827, 9387, 21137, 6184, 1000],
#  [41950, 28842, 19446, 26209, 46676, 25093, 38057, 14462, 25890],
#  [27086,
#   30776,
#   49247,
#   22537,
#   49131,
#   24852,
#   23375,
#   29307,
#   13712,
#   47993,
#   2043,
#   25588,
#   8277,
#   22151,
#   34993,
#   17691,
#   4920],
#  [45007, 44359, 42701, 5876, 19057, 24058, 17948, 25659, 18362],
#  [18479, 24852, 21137, 44765, 21267, 7175, 17419, 34525, 5206],
#  [24852, 47630, 46969, 22825, 9561, 19057, 8277],
#  [20114,
#   26209,
#   5876,
#   24184,
#   34196,
#   28842,
#   2010,
#   19185,
#   2581,
#   27344,
#   38558,
#   27841,
#   9477,
#   41950,
#   36793,
#   43867,
#   34126,
#   19736,
#   46107,
#   8767],
#  [23081, 21841, 31880, 40427, 31910, 41787, 28985],
#  [25588, 21137, 33443, 3765, 31553, 44570, 30994, 14199, 42221, 48622],
#  [14715, 19972],
#  [15143, 3717, 49667, 31461, 28458, 7398, 12324, 41005, 14870],
#  ...]

# %%
# cria coluna de pedidos
order_ = order_grouped[0]
order_
# Out:
# 0                2
# 1                3
# 2                4
# 3                5
# 4                6
#             ...
# 3214869    3421079
# 3214870    3421080
# 3214871    3421081
# 3214872    3421082
# 3214873    3421083
# Name: 0, Length: 3214874, dtype: int64

# %%
# Prepara o dataframe sendo a coluna OrdeID id do pedido e Products id do produto de cada pedido
transactions = pd.DataFrame({'OrderID' : order_, 'Products' : prod_})

# %%
transactions.head(10)
# Out:
#    OrderID                                           Products
# 0        2  [33120, 28985, 9327, 45918, 30035, 17794, 4014...
# 1        3  [33754, 24838, 17704, 21903, 17668, 46667, 174...
# 2        4  [46842, 26434, 39758, 27761, 10054, 21351, 225...
# 3        5  [13176, 15005, 47329, 27966, 23909, 48370, 132...
# 4        6                              [40462, 15873, 41897]
# 5        7                                     [34050, 46802]
# 6        8                                            [23423]
# 7        9  [21405, 47890, 11182, 2014, 29193, 34203, 1499...
# 8       10  [24852, 4796, 31717, 47766, 4605, 1529, 21137,...
# 9       11                  [30162, 27085, 5994, 1313, 31506]

# %% [markdown]
# ## Análise Estatística Descritiva

# %% [markdown]
# ### 1- Qual o Número de Pedidos Mais Frequente Entre os Usuários?

# %%
# Agrupa os dados por id do usuário e número de pedidos, agregando pelo maior valor
# Ou seja, o usuario user_id 1 fez 11 pedidos até o momento.
ord_max_count = order.groupby("user_id")['order_number'].aggregate(np.max).reset_index()
ord_max_count.head()
# Out:
#    user_id  order_number
# 0        1            11
# 1        2            15
# 2        3            13
# 3        4             6
# 4        5             5

# %%
# Faz a contagem dos usurios que realizaram um determinado número de pedidos.
ord_max_count = ord_max_count.order_number.value_counts()
ord_max_count.head()
# Out:
# 4    23986
# 5    19590
# 6    16165
# 7    13850
# 8    11700
# Name: order_number, dtype: int64

# %%
# Plot
plt.style.use('ggplot')
plt.figure(figsize = (20,8))
plt.bar(ord_max_count.index, ord_max_count.values, color = 'indigo', width = 0.6)
plt.xticks(ord_max_count.index, rotation = 'vertical')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.xlabel('Número de Pedidos Mais Frequente Entre os Usuários', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 2- Qual Dia da Semana Tem o Maior Número de Pedidos?

# %%
# Frequências de pedidos por dia da semana (dow = day of the week)
# vetor y conta quantos pedidos foram realizados quando dow era de 0 a 6.
x = [0,1,2,3,4,5,6]
y = [order[order['order_dow']==0].shape[0],
     order[order['order_dow']==1].shape[0],
     order[order['order_dow']==2].shape[0],
     order[order['order_dow']==3].shape[0],
     order[order['order_dow']==4].shape[0],
     order[order['order_dow']==5].shape[0],
     order[order['order_dow']==6].shape[0]]

# %%
# Plot
plt.figure(figsize = (10,5))
plt.bar(x,y, color = 'slateblue')
plt.xlabel('Dia da Semana', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.xticks(x,['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado'], rotation = 'horizontal')
plt.show()

# %% [markdown]
# O dia da semana com maior frequencia de vendas é o domingo, em seguida a segunda-feira

# %% [markdown]
# ### 3- Qual Hora do Dia Tem o Maior Número de Pedidos?

# %%
# Frequências de pedidos pela hora do dia
# vetor y conta o numero de pedidos quando o order_hour_of_day era de 0 a 23
x = list(range(0,24))
y = []
for i in range(24):
    y.append(order[order['order_hour_of_day']==i].shape[0])
y
# Out:
# [22758,
#  12398,
#  7539,
#  5474,
#  5527,
#  9569,
#  30529,
#  91868,
#  178201,
#  257812,
#  288418,
#  284728,
#  272841,
#  277999,
#  283042,
#  283639,
#  272553,
#  228795,
#  182912,
#  140569,
#  104292,
#  78109,
#  61468,
#  40043]

# %%
# Plot
plt.figure(figsize = (20,5))
plt.bar(x,y,color = 'forestgreen')
plt.xticks(np.arange(0,24,1))
plt.xlabel('Hora do Dia', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 4- Qual Departamento Tem o Maior Número de Pedidos?

# %%
# Contagem de pedidos por departamento
# Conta o numero de pedidos por departamento no dataframe q geramos order_product_prior
dept_cnt = order_product_prior['department'].value_counts()

# %%
# Plot
fig = plt.figure(figsize = (20,10))
dept_cnt.plot(kind = "bar", color = 'maroon')
plt.xticks(rotation = 90)
plt.xlabel('Departamento', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 5- Quais os 20 Principais Corredores Por Frequência de Pedidos?

# %%
# Conta o numero de pedidos por corredor
aisle_cnt = order_product_prior['aisle'].value_counts()
aisle_cnt.head()
# Out:
# fresh fruits                  3642188
# fresh vegetables              3418021
# packaged vegetables fruits    1765313
# yogurt                        1452343
# packaged cheese                979763
# Name: aisle, dtype: int64

# %%
# Plot
fig = plt.figure(figsize = (20,10))
# seleciona apenas os 20 corredores com maior numero de pedidos
aisle_cnt[0:20].plot(kind = "bar", color = 'darkgoldenrod')
plt.xticks(rotation = 90)
plt.xlabel('Corredor', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 6- Quais os 20 Principais Produtos Por Frequência de Pedidos?

# %%
# Conta o numero de produtos por pedido
prod_cnt = order_product_prior['product_name'].value_counts()
prod_cnt.head()
# Out:
# Banana                    472565
# Bag of Organic Bananas    379450
# Organic Strawberries      264683
# Organic Baby Spinach      241921
# Organic Hass Avocado      213584
# Name: product_name, dtype: int64

# %%
# Plot
fig = plt.figure(figsize = (20,10))
# seleciona apenas os 20 produtos com maior frequencia nos pedidos
prod_cnt[0:20].plot(kind = "bar", color = 'purple')
plt.xticks(rotation = 90)
plt.xlabel('Produto', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 7- Análise de Novos Pedidos Semelhantes a Pedidos Anteriores (reorder)

# %%
# Conta o numero do produto por pedido e soma o numero de vezes q foi reorder do produto
temp_df = order_product_prior.groupby("product_name")["reordered"].agg(['count', 'sum']).rename(columns = {'count':'total','sum':'reorders'})
temp_df = temp_df.sort_values('total', ascending = False).reset_index()
temp_df.head()
# Out:
#              product_name   total  reorders
# 0                  Banana  472565    398609
# 1  Bag of Organic Bananas  379450    315913
# 2    Organic Strawberries  264683    205845
# 3    Organic Baby Spinach  241921    186884
# 4    Organic Hass Avocado  213584    170131

# %%
# Prepara as listas 
labels = list(temp_df.product_name[0:20])
reorder = list(temp_df.reorders[0:20])
total = list(temp_df.total[0:20])

# %%
# Plot  
width = 0.35 
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(labels, reorder, width, label = 'Reorder', color = 'green')
ax.bar(labels, total, width, bottom = reorder, label = 'Total', color = 'red')
ax.set_ylabel('Total de Pedidos', fontsize = 14, fontweight = 'bold')
ax.legend()
ax.set_title("Produtos Mais Populares")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### 7- Análise de Reorder Por Departamento ao Longo do Tempo

# %%
# Agrupando os dados por departamento e reorder
grouped_df = order_product_prior.groupby(["department"])["reordered"].aggregate("mean").reset_index()
grouped_df = grouped_df.sort_values('reordered', ascending = True)
grouped_df.head()
# Out:
#        department  reordered
# 17  personal care   0.321129
# 16         pantry   0.346721
# 12  international   0.369229
# 14        missing   0.395849
# 11      household   0.402178

# %%
# Plot
plt.figure(figsize = (12,8))
plt.plot(list(grouped_df['department']), grouped_df['reordered'].values, alpha=0.8)
plt.scatter(list(grouped_df['department']), grouped_df['reordered'].values)
plt.ylabel('Taxa de Reorder', fontsize = 12)
plt.xlabel('Departmento', fontsize = 12)
plt.title("Departmento x Taxa de Reorder", fontsize = 15)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### 8- Análise de Reorder e Pedidos

# %%
# analise de pedidos e reorder por departamento
# Conta o numero de pedidos por departamento e soma o numero de vezes q houve reorder do departamento
temp_df = order_product_prior.groupby("department")["reordered"].agg(['count', 'sum']).rename(columns = {'count':'total','sum':'reorders'})
temp_df = temp_df.sort_values('total', ascending = False).reset_index()
temp_df.head()
# Out:
#    department    total  reorders
# 0     produce  9479291   6160710
# 1  dairy eggs  5414016   3627221
# 2      snacks  2887550   1657973
# 3   beverages  2690129   1757892
# 4      frozen  2236432   1211890

# %%
# Listas
labels = list(temp_df.department[0:20])
reorder = list(temp_df.reorders[0:20])
total = list(temp_df.total[0:20])

# %%
# Plot
width = 0.35  
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(labels, reorder, width, label = 'Reorder', color = 'magenta')
ax.bar(labels, total, width, bottom = reorder, label = 'Pedidos', color = 'blue')
ax.set_ylabel('Total de Pedidos', fontsize = 14, fontweight = 'bold')
ax.legend()
ax.set_title("Total de Pedidos e Reorders por Departmento")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### 9- Análise de Reorder Por Corredor

# %%
# analise de reorder por corredor
grouped_df = order_product_prior.groupby(["aisle"])["reordered"].aggregate("mean").reset_index()
grouped_df = grouped_df.sort_values('reordered', ascending = True)
grouped_df.head()
# Out:
#                      aisle  reordered
# 122      spices seasonings   0.152391
# 7    baking supplies decor   0.167229
# 47               first aid   0.194812
# 76        kitchen supplies   0.195377
# 8                   beauty   0.212062

# %%
list(grouped_df['aisle'])[0:20]
# Out:
# ['air fresheners candles',
#  'asian foods',
#  'baby accessories',
#  'baby bath body care',
#  'baby food formula',
#  'bakery desserts',
#  'baking ingredients',
#  'baking supplies decor',
#  'beauty',
#  'beers coolers',
#  'body lotions soap',
#  'bread',
#  'breakfast bakery',
#  'breakfast bars pastries',
#  'bulk dried fruits vegetables',
#  'bulk grains rice dried goods',
#  'buns rolls',
#  'butter',
#  'candy chocolate',
#  'canned fruit applesauce']

# %%
# Corredor x Taxa de Reorder
plt.figure(figsize=(14,7))
plt.plot(list(grouped_df['aisle'])[0:20], grouped_df['reordered'].values[0:20], alpha=0.8)
plt.scatter(list(grouped_df['aisle'])[0:20], grouped_df['reordered'].values[0:20])
plt.ylabel('Taxa de Reorder', fontsize=12)
plt.xlabel('Corredor', fontsize=12)
plt.title("Corredor x Taxa de Reorder", fontsize = 15)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### 10- Análise de Reorder Por Corredor (Total)

# %%
# analise de total de pedidos e reorder por corredor
temp_df = order_product_prior.groupby("aisle")["reordered"].agg(['count', 'sum']).rename(columns = {'count':'total','sum':'reorders'})
temp_df = temp_df.sort_values('total', ascending = False).reset_index()
temp_df.head()
# Out:
#                         aisle    total  reorders
# 0                fresh fruits  3642188   2615469
# 1            fresh vegetables  3418021   2032172
# 2  packaged vegetables fruits  1765313   1127177
# 3                      yogurt  1452343    997018
# 4             packaged cheese   979763    573383

# %%
# Listas
labels = list(temp_df.aisle[0:20])
reorder = list(temp_df.reorders[0:20])
total = list(temp_df.total[0:20])

# %%
# Plot
width = 0.35      
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(labels, reorder, width, label = 'Reorder', color = 'green')
ax.bar(labels, total, width, bottom = reorder, label = 'Total', color = 'red')
ax.set_ylabel('Total de Pedidos', fontsize = 14, fontweight = 'bold')
ax.legend()
ax.set_title("Total de Pedidos e Reorders por Corredor")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# > Vamos verificar a relação entre como a ordem de adição do produto ao carrinho afeta a proporção de novos pedidos

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -q shutup

# %%
import shutup; shutup.please()

# %%
# Criamos uma nova coluna no order_product_prior denominada 'add_to_cart_order_mod'
# Em seguida criamos novo dataframe 'grouped_df' como coluna 'add_to_cart_order_mod' e média da ordem q 
# foi adicionado ao carrinho
order_product_prior["add_to_cart_order_mod"] = order_product_prior["add_to_cart_order"].copy()
order_product_prior["add_to_cart_order_mod"].loc[order_product_prior["add_to_cart_order_mod"] > 70] = 70
grouped_df = order_product_prior.groupby(["add_to_cart_order_mod"])["reordered"].aggregate("mean").reset_index()

# %%
order_product_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
#
#             product_name  aisle_id  department_id               aisle  \
# 0     Organic Egg Whites        86             16                eggs
# 1  Michigan Organic Kale        83              4    fresh vegetables
# 2          Garlic Powder       104             13   spices seasonings
# 3         Coconut Butter        19             13       oils vinegars
# 4      Natural Sweetener        17             13  baking ingredients
#
#    department  add_to_cart_order_mod
# 0  dairy eggs                      1
# 1     produce                      2
# 2      pantry                      3
# 3      pantry                      4
# 4      pantry                      5

# %%
grouped_df.head()
# Out:
#    add_to_cart_order_mod  reordered
# 0                      1   0.677533
# 1                      2   0.676251
# 2                      3   0.658037
# 3                      4   0.636958
# 4                      5   0.617383

# %% [markdown]
# ## Implementação do Algoritmo Apriori

# %% [markdown]
# Métricas:
#
# ![title](imagens/regras.png)

# %% [markdown]
# Support = Fração de transações que contêm A e B.
#
# ![title](imagens/support.png)

# %% [markdown]
# Confidence = A frequência com que B aparece em transações que contêm apenas A.
#
# ![title](imagens/confidence.png)

# %% [markdown]
# Lift = Quanto aumentou nossa confiança de que B será comprado, dado que A foi comprado.
#
# ![title](imagens/lift.png)

# %%
# Prepara a tupla com as transações
# dataframe transactions foi criada anteriormente
transactions_tup = [tuple(row) for row in transactions['Products'].tolist()]

# %% [markdown]
# ### Executa o Algoritmo Apriori Com Support = 0.01 e Confidence = 0.2

# %%
st = datetime.now()
# filtra apenas 500000 registros
itemsets_ap, rules_ap = apriori(transactions_tup[:500000], min_support = 0.01, min_confidence = 0.2)
print('Tempo de Execução : ', datetime.now() - st)
# Out:
# Tempo de Execução :  0:00:07.654008

# %%
# As regras de associação
rules_ap
# Out:
# [{21137} -> {13176},
#  {21903} -> {13176},
#  {27966} -> {13176},
#  {47209} -> {13176},
#  {16797} -> {24852},
#  {21137} -> {24852},
#  {27966} -> {21137},
#  {21903} -> {24852},
#  {28204} -> {24852},
#  {47626} -> {24852},
#  {47766} -> {24852},
#  {49683} -> {24852}]

# %%
# Listas de itens para considerar
item_A = [27966,47209,21137,47766,21903,49683,47626,28204,16797,21903,21137,27966]
item_B = [13176,13176,24852,24852,24852,24852,24852,24852,24852,13176,13176,21137]
temp = pd.DataFrame()
temp['itemA'] = item_A
temp['itemB'] = item_B

# %%
# Listas para as métricas
support_A = []
support_B = []
support_AB = []
confidence_AB = []
lift_AB = []

# %%
# Loop
for i in range(len(temp)):
    
    # Calcula o support de A
    support_A.append(itemsets_ap[1][tuple([temp['itemA'][i],])] / 500000)
    
    # Calcula o support de B
    support_B.append(itemsets_ap[1][tuple([temp['itemB'][i],])] / 500000)
    
    # Calcula o support de A e B
    if tuple([temp['itemA'][i],temp['itemB'][i]]) in itemsets_ap[2].keys():
        support_AB.append(itemsets_ap[2][tuple([temp['itemA'][i],temp['itemB'][i]])] / 500000)
    else:
        support_AB.append(itemsets_ap[2][tuple([temp['itemB'][i],temp['itemA'][i]])] / 500000)
    
    # Calcula a confidence
    confidence_AB.append(support_AB[i] / support_A[i])
    
    # Calcula o lift
    lift_AB.append(support_AB[i] / (support_A[i] * support_B[i]))

# %%
# Dataframe com as regras de associação
df_rules_ap = pd.DataFrame()
df_rules_ap['product_id'] = item_A
df_rules_ap = df_rules_ap.merge(product, on = 'product_id', how = 'left')
df_rules_ap['Product_A'] = df_rules_ap['product_name']
df_rules_ap = df_rules_ap.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap['product_id'] = item_B
df_rules_ap = df_rules_ap.merge(product, on = 'product_id', how = 'left')
df_rules_ap['Product_B'] = df_rules_ap['product_name']
df_rules_ap = df_rules_ap.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap['Support_A'] = support_A
df_rules_ap['Support_B'] = support_B
df_rules_ap['Support_AB'] = support_AB
df_rules_ap['Confidence_AB'] = confidence_AB
df_rules_ap['Lift_AB'] = lift_AB

# %%
# Confidence = A frequência com que B aparece em transações que contêm apenas A.
df_rules_ap.sort_values(by = 'Confidence_AB', ascending = False)
# Out:
#                Product_A               Product_B  Support_A  Support_B  \
# 7     Organic Fuji Apple                  Banana   0.027942   0.147194
# 5         Cucumber Kirby                  Banana   0.030218   0.147194
# 3        Organic Avocado                  Banana   0.054564   0.147194
# 0    Organic Raspberries  Bag of Organic Bananas   0.042334   0.117802
# 1   Organic Hass Avocado  Bag of Organic Bananas   0.066218   0.117802
# 8           Strawberries                  Banana   0.044496   0.147194
# 6            Large Lemon                  Banana   0.047718   0.147194
# 11   Organic Raspberries    Organic Strawberries   0.042334   0.082550
# 10  Organic Strawberries  Bag of Organic Bananas   0.082550   0.117802
# 4   Organic Baby Spinach                  Banana   0.075000   0.147194
# 2   Organic Strawberries                  Banana   0.082550   0.147194
# 9   Organic Baby Spinach  Bag of Organic Bananas   0.075000   0.117802
#
#     Support_AB  Confidence_AB   Lift_AB
# 7     0.010630       0.380431  2.584554
# 5     0.010024       0.331723  2.253644
# 3     0.016328       0.299245  2.032997
# 0     0.012428       0.293570  2.492064
# 1     0.019260       0.290857  2.469037
# 8     0.012902       0.289959  1.969908
# 6     0.012692       0.265979  1.806998
# 11    0.010524       0.248595  3.011442
# 10    0.019122       0.231641  1.966362
# 4     0.016016       0.213547  1.450784
# 2     0.017596       0.213156  1.448127
# 9     0.015500       0.206667  1.754356

# %%
# Lift = Quanto aumentou nossa confiança de que B será comprado, dado que A foi comprado.
df_rules_ap.sort_values(by = 'Lift_AB', ascending = False)
# Out:
#                Product_A               Product_B  Support_A  Support_B  \
# 11   Organic Raspberries    Organic Strawberries   0.042334   0.082550
# 7     Organic Fuji Apple                  Banana   0.027942   0.147194
# 0    Organic Raspberries  Bag of Organic Bananas   0.042334   0.117802
# 1   Organic Hass Avocado  Bag of Organic Bananas   0.066218   0.117802
# 5         Cucumber Kirby                  Banana   0.030218   0.147194
# 3        Organic Avocado                  Banana   0.054564   0.147194
# 8           Strawberries                  Banana   0.044496   0.147194
# 10  Organic Strawberries  Bag of Organic Bananas   0.082550   0.117802
# 6            Large Lemon                  Banana   0.047718   0.147194
# 9   Organic Baby Spinach  Bag of Organic Bananas   0.075000   0.117802
# 4   Organic Baby Spinach                  Banana   0.075000   0.147194
# 2   Organic Strawberries                  Banana   0.082550   0.147194
#
#     Support_AB  Confidence_AB   Lift_AB
# 11    0.010524       0.248595  3.011442
# 7     0.010630       0.380431  2.584554
# 0     0.012428       0.293570  2.492064
# 1     0.019260       0.290857  2.469037
# 5     0.010024       0.331723  2.253644
# 3     0.016328       0.299245  2.032997
# 8     0.012902       0.289959  1.969908
# 10    0.019122       0.231641  1.966362
# 6     0.012692       0.265979  1.806998
# 9     0.015500       0.206667  1.754356
# 4     0.016016       0.213547  1.450784
# 2     0.017596       0.213156  1.448127

# %% [markdown]
# ### Executa o Algoritmo Apriori Com Support = 0.005 e Confidence = 0.2

# %%
st = datetime.now()
itemsets_ap_1, rules_ap_1 = apriori(transactions_tup[:500000], min_support = 0.005, min_confidence = 0.2)
print('Tempo de Execução: ', datetime.now() - st)
# Out:
# Tempo de Execução:  0:00:07.297693

# %%
# As regras de associação
rules_ap_1
# Out:
# [{4605} -> {24852},
#  {4920} -> {24852},
#  {5876} -> {13176},
#  {5876} -> {47209},
#  {8277} -> {13176},
#  {8277} -> {24852},
#  {9076} -> {24852},
#  {19057} -> {13176},
#  {21137} -> {13176},
#  {21903} -> {13176},
#  {22935} -> {13176},
#  {27966} -> {13176},
#  {30391} -> {13176},
#  {37646} -> {13176},
#  {39275} -> {13176},
#  {45007} -> {13176},
#  {47209} -> {13176},
#  {16797} -> {24852},
#  {21137} -> {24852},
#  {27966} -> {21137},
#  {30391} -> {21137},
#  {39275} -> {21137},
#  {21903} -> {24852},
#  {24964} -> {22935},
#  {26209} -> {24852},
#  {27845} -> {24852},
#  {28204} -> {24852},
#  {30489} -> {24852},
#  {37646} -> {24852},
#  {40706} -> {24852},
#  {42265} -> {24852},
#  {44632} -> {24852},
#  {45066} -> {24852},
#  {47626} -> {24852},
#  {47766} -> {24852},
#  {49683} -> {24852},
#  {31717} -> {26209},
#  {30391} -> {47209}]

# %% [markdown]
# Observa-se que um aumento na acurácia do modelo aumento ainda mais as regras de associação

# %%
# Lista de itens para considerar
item_A1 = [27966,47209,4605,21137,47766,21903,49683,5876,37646,40706,47626,5876,30391,22935,37646,31717,
           28204,27845,24964,45066,9076,16797,21903,8277,30391,21137,27966,19057,26209,45007,39275,30489,
           42265,30391,8277,4920,39275,44632]
item_B1 = [13176,13176,24852,24852,24852,24852,24852,47209,24852,24852,24852,13176,13176,13176,13176,26209,
           24852,24852,22935,24852,24852,24852,13176,24852,47209,13176,21137,13176,24852,13176,21137,24852,
           24852,21137,13176,24852,13176,24852]
temp1 = pd.DataFrame()
temp1['itemA'] = item_A1
temp1['itemB'] = item_B1

# %%
# Listas de métricas
support_A1 = []
support_B1 = []
support_AB1 = []
confidence_AB1 = []
lift_AB1 = []

# %%
# Loop
for i in range(len(temp1)):
    
    support_A1.append(itemsets_ap_1[1][tuple([temp1['itemA'][i],])] / 500000)
    
    support_B1.append(itemsets_ap_1[1][tuple([temp1['itemB'][i],])] / 500000)
    
    if tuple([temp1['itemA'][i],temp1['itemB'][i]]) in itemsets_ap_1[2].keys():
        support_AB1.append(itemsets_ap_1[2][tuple([temp1['itemA'][i],temp1['itemB'][i]])] / 500000)
    else:
        support_AB1.append(itemsets_ap_1[2][tuple([temp1['itemB'][i],temp1['itemA'][i]])] / 500000)
    
    confidence_AB1.append(support_AB1[i] / support_A1[i])
    
    lift_AB1.append(support_AB1[i] / (support_A1[i] * support_B1[i]))

# %%
# Dataframe com as regras de associação
df_rules_ap1 = pd.DataFrame()
df_rules_ap1['product_id'] = item_A1
df_rules_ap1 = df_rules_ap1.merge(product, on = 'product_id', how = 'left')
df_rules_ap1['Product_A'] = df_rules_ap1['product_name']
df_rules_ap1 = df_rules_ap1.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap1['product_id'] = item_B1
df_rules_ap1 = df_rules_ap1.merge(product, on = 'product_id', how = 'left')
df_rules_ap1['Product_B'] = df_rules_ap1['product_name']
df_rules_ap1 = df_rules_ap1.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap1['Support_A'] = support_A1
df_rules_ap1['Support_B'] = support_B1
df_rules_ap1['Support_AB'] = support_AB1
df_rules_ap1['Confidence_AB'] = confidence_AB1
df_rules_ap1['Lift_AB'] = lift_AB1

# %%
# Confidence = A frequência com que B aparece em transações que contêm apenas A.
df_rules_ap1.sort_values(by = 'Confidence_AB', ascending = False).head(10)
# Out:
#                                Product_A               Product_B  Support_A  \
# 16                    Organic Fuji Apple                  Banana   0.027942
# 19                      Honeycrisp Apple                  Banana   0.024774
# 6                         Cucumber Kirby                  Banana   0.030218
# 27  Organic Large Extra Fancy Fuji Apple  Bag of Organic Bananas   0.023374
# 4                        Organic Avocado                  Banana   0.054564
# 35                   Seedless Red Grapes                  Banana   0.026054
# 2                          Yellow Onions                  Banana   0.022814
# 0                    Organic Raspberries  Bag of Organic Bananas   0.042334
# 20                           Blueberries                  Banana   0.017674
# 1                   Organic Hass Avocado  Bag of Organic Bananas   0.066218
#
#     Support_B  Support_AB  Confidence_AB   Lift_AB
# 16   0.147194    0.010630       0.380431  2.584554
# 19   0.147194    0.008832       0.356503  2.421993
# 6    0.147194    0.010024       0.331723  2.253644
# 27   0.117802    0.007330       0.313596  2.662063
# 4    0.147194    0.016328       0.299245  2.032997
# 35   0.147194    0.007750       0.297459  2.020864
# 2    0.147194    0.006750       0.295871  2.010075
# 0    0.117802    0.012428       0.293570  2.492064
# 20   0.147194    0.005186       0.293425  1.993460
# 1    0.117802    0.019260       0.290857  2.469037

# %%
# Lift = Quanto aumentou nossa confiança de que B será comprado, dado que A foi comprado.
df_rules_ap1.sort_values(by = 'Lift_AB', ascending = False).head(10)
# Out:
#                                Product_A               Product_B  Support_A  \
# 15                      Organic Cilantro                   Limes   0.021334
# 18                        Organic Garlic    Organic Yellow Onion   0.034158
# 7                          Organic Lemon    Organic Hass Avocado   0.027242
# 24                      Organic Cucumber    Organic Hass Avocado   0.025056
# 26                   Organic Raspberries    Organic Strawberries   0.042334
# 30                   Organic Blueberries    Organic Strawberries   0.031188
# 27  Organic Large Extra Fancy Fuji Apple  Bag of Organic Bananas   0.023374
# 16                    Organic Fuji Apple                  Banana   0.027942
# 0                    Organic Raspberries  Bag of Organic Bananas   0.042334
# 33                      Organic Cucumber    Organic Strawberries   0.025056
#
#     Support_B  Support_AB  Confidence_AB   Lift_AB
# 15   0.043640    0.005342       0.250398  5.737819
# 18   0.035306    0.006868       0.201066  5.694942
# 7    0.066218    0.006534       0.239850  3.622130
# 24   0.066218    0.005396       0.215358  3.252252
# 26   0.082550    0.010524       0.248595  3.011442
# 30   0.082550    0.007284       0.233551  2.829211
# 27   0.117802    0.007330       0.313596  2.662063
# 16   0.147194    0.010630       0.380431  2.584554
# 0    0.117802    0.012428       0.293570  2.492064
# 33   0.082550    0.005138       0.205061  2.484078

# %% [markdown]
# ## Conclusão
#
# Aplicando Matemática e Estatística via programação executamos uma análise de MBA gerando como resultado as regras de associação entre os produtos com diferentes métricas.
